# %%
# !pip install chromedriver_autoinstaller
# Out:
# Collecting chromedriver_autoinstaller
#   Downloading chromedriver_autoinstaller-0.4.0-py3-none-any.whl (6.5 kB)
# Installing collected packages: chromedriver_autoinstaller
# Successfully installed chromedriver_autoinstaller-0.4.0

# %%
# !pip3 install beautifulsoup4
# !pip install selenium
# !pip install newspaper3k
# !pip3 install keybert
nltk.download('all')
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\nh\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nh\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.1)
# Requirement already satisfied: selenium in c:\users\nh\anaconda3\lib\site-packages (4.7.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\nh\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: trio~=0.17 in c:\users\nh\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\nh\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\nh\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: outcome in c:\users\nh\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\nh\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: idna in c:\users\nh\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\nh\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\nh\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: sniffio in c:\users\nh\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\nh\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\nh\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: wsproto>=0.14 in c:\users\nh\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\nh\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\nh\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\nh\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: newspaper3k in c:\users\nh\anaconda3\lib\site-packages (0.2.8)
# Requirement already satisfied: Pillow>=3.3.0 in c:\users\nh\anaconda3\lib\site-packages (from newspaper3k) (9.2.0)
# Requirement already satisfied: lxml>=3.6.0 in c:\users\nh\anaconda3\lib\site-packages (from newspaper3k) (4.9.1)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\nh\anaconda3\lib\site-packages (from newspaper3k) (4.11.1)
# Requirement already satisfied: tldextract>=2.0.1 in c:\users\nh\anaconda3\lib\site-packages (from newspaper3k) (3.2.0)
# Requirement already satisfied: feedfinder2>=0.0.4 in c:\users\nh\anaconda3\lib\site-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: PyYAML>=3.11 in c:\users\nh\anaconda3\lib\site-packages (from newspaper3k) (6.0)
# Requirement already satisfied: feedparser>=5.2.1 in c:\users\nh\anaconda3\lib\site-packages (from newspaper3k) (6.0.10)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\nh\anaconda3\lib\site-packages (from newspaper3k) (2.8.2)
# Requirement already satisfied: requests>=2.10.0 in c:\users\nh\anaconda3\lib\site-packages (from newspaper3k) (2.28.1)
# Requirement already satisfied: jieba3k>=0.35.1 in c:\users\nh\anaconda3\lib\site-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: cssselect>=0.9.2 in c:\users\nh\anaconda3\lib\site-packages (from newspaper3k) (1.1.0)
# Requirement already satisfied: nltk>=3.2.1 in c:\users\nh\anaconda3\lib\site-packages (from newspaper3k) (3.7)
# Requirement already satisfied: tinysegmenter==0.3 in c:\users\nh\anaconda3\lib\site-packages (from newspaper3k) (0.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nh\anaconda3\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.3.1)
# Requirement already satisfied: six in c:\users\nh\anaconda3\lib\site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Requirement already satisfied: sgmllib3k in c:\users\nh\anaconda3\lib\site-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: tqdm in c:\users\nh\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (4.64.1)
# Requirement already satisfied: joblib in c:\users\nh\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\nh\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (2022.7.9)
# Requirement already satisfied: click in c:\users\nh\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (8.0.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\nh\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nh\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nh\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nh\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (1.26.11)
# Requirement already satisfied: requests-file>=1.4 in c:\users\nh\anaconda3\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\nh\anaconda3\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (3.6.0)
# Requirement already satisfied: colorama in c:\users\nh\anaconda3\lib\site-packages (from click->nltk>=3.2.1->newspaper3k) (0.4.5)

# %%
import requests 
from bs4 import BeautifulSoup
import re
from tqdm import tqdm
import time
import numpy
import random
import pickle
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from datetime import datetime
import pandas as pd
from newspaper import Article
import os
import nltk

# %%
from selenium.webdriver.chrome.options import Options
import chromedriver_autoinstaller
import subprocess
import shutil

try:
    shutil.rmtree(r"c:\chrometemp")  #쿠키 / 캐쉬파일 삭제
except FileNotFoundError:
    pass

subprocess.Popen(r'C:\Program Files\Google\Chrome\Application\chrome.exe --remote-debugging-port=9222 --user-data-dir="C:\chrometemp"') # 디버거 크롬 구동


option = Options()
option.add_experimental_option("debuggerAddress", "127.0.0.1:9222")

chrome_ver = chromedriver_autoinstaller.get_chrome_version().split('.')[0]
try:
    driver = webdriver.Chrome(f'./{chrome_ver}/chromedriver.exe', options=option)
except:
    chromedriver_autoinstaller.install(True)
    driver = webdriver.Chrome(f'./{chrome_ver}/chromedriver.exe', options=option)
driver.implicitly_wait(10)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8596\1447849451.py in <module>
#       5
#       6 try:
# ----> 7     shutil.rmtree(r"c:\chrometemp")  #쿠키 / 캐쉬파일 삭제
#       8 except FileNotFoundError:
#       9     pass
#
# ~\anaconda3\lib\shutil.py in rmtree(path, ignore_errors, onerror)
#     757             # can't continue even if onerror hook returns
#     758             return
# --> 759         return _rmtree_unsafe(path, onerror)
#     760
#     761 # Allow introspection of whether or not the hardening against symlink
#
# ~\anaconda3\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     622                 onerror(os.path.islink, fullname, sys.exc_info())
#     623                 continue
# --> 624             _rmtree_unsafe(fullname, onerror)
#     625         else:
#     626             try:
#
# ~\anaconda3\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     627                 os.unlink(fullname)
#     628             except OSError:
# --> 629                 onerror(os.unlink, fullname, sys.exc_info())
#     630     try:
#     631         os.rmdir(path)
#
# ~\anaconda3\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     625         else:
#     626             try:
# --> 627                 os.unlink(fullname)
#     628             except OSError:
#     629                 onerror(os.unlink, fullname, sys.exc_info())
#
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'c:\\chrometemp\\Default\\Affiliation Database'

# %%
from_date = '2023-2-14'
to_date = '2023-2-14'
searching_word = 'economy'
cwd = os.getcwd()
main_path = cwd + '/' + searching_word

# %%
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

createFolder(main_path)
createFolder(main_path + '/' + 'url')
createFolder(main_path + '/' + 'news_backup')
createFolder(main_path + '/' + 'news')
createFolder(main_path + '/' + 'keyword')

# 1 키워드 검색 뉴스 url 수집
def page2url(searching_word,date):
    searching_word = '"{}"'.format(searching_word)
    urls = []
    for start in range(0, 360, 10):
        main_url = 'https://www.google.co.kr/search?q={}&tbs=cdr:1,cd_min:{},cd_max:{}&tbm=nws&ei=dPP-Yu_eCJLL-Qb55bvQDA&start={}&sa=N&ved=2ahUKEwjv6Lvy69H5AhWSZd4KHfnyDso4ChDy0wN6BAgBEDk&biw=1536&bih=754&dpr=1.25'.format(searching_word,date,date,start)
        driver.get(url=main_url)
        elements = driver.find_elements(By.TAG_NAME, 'a')
        lnks = []
        for lnk in elements:
            lnk = str(lnk.get_attribute('href'))
            if 'google' not in lnk and lnk != 'None':
                lnks.append(lnk)
        if len(lnks) == 0:
            print(date, ' Url 수집 완료')
            break
        urls.extend(lnks)
        rand_value =random.uniform(4, 10)
        time.sleep(rand_value)
        
    return urls

datelist = pd.date_range(start=from_date, end=to_date).tolist()
dtlst = []
for d_t in datelist:
    d_t = str(d_t)[0:-9]
    d = datetime.strptime(d_t, '%Y-%m-%d')
    d = d.strftime('%m/%d/%Y')
    d = d[0].replace('0','') + d[1:]
    d = d[:-7] + d[-7].replace('0','') + d[-6:]
    dtlst.append(d)
    
    
Urls = dict()
for date in tqdm(dtlst):
    print(date,'Url 수집 시작')
    urls = page2url(searching_word,date)
    Urls[date] = urls
    
name = "Urls{}-{}.pickle".format(from_date,to_date)
name = name.replace('/','.')

with open(main_path + '/' + 'url/' + name,'wb') as f:
    pickle.dump(Urls,f)
# Out:
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 2/14/2023 Url 수집 시작
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1252\1485611859.py in <module>
#      48 for date in tqdm(dtlst):
#      49     print(date,'Url 수집 시작')
# ---> 50     urls = page2url(searching_word,date)
#      51     Urls[date] = urls
#      52
#
# ~\AppData\Local\Temp\ipykernel_1252\1485611859.py in page2url(searching_word, date)
#      18     for start in range(0, 360, 10):
#      19         main_url = 'https://www.google.co.kr/search?q={}&tbs=cdr:1,cd_min:{},cd_max:{}&tbm=nws&ei=dPP-Yu_eCJLL-Qb55bvQDA&start={}&sa=N&ved=2ahUKEwjv6Lvy69H5AhWSZd4KHfnyDso4ChDy0wN6BAgBEDk&biw=1536&bih=754&dpr=1.25'.format(searching_word,date,date,start)
# ---> 20         driver.get(url=main_url)
#      21         elements = driver.find_elements(By.TAG_NAME, 'a')
#      22         lnks = []
#
# NameError: name 'driver' is not defined

# %%
name = "Urls{}-{}.pickle".format(from_date,to_date)
name = name.replace('/','.')
# 2  수집된 url로 news 크롤링 
with open(main_path + '/' + 'url/' + name, 'rb') as f:
    data = pickle.load(f)

# start = 0
for date in list(data):
    print(date, '크롤링 시작')
    cnt = 0
    tmp = []
    urls = []
    for idx,url in tqdm(enumerate(data[date][0:10])):
        try:
            article = Article(url)
            article.download()
            article.parse()
            v = article.text
            tmp.append(v)
            urls.append(url)
            cnt += 1
        except:
            pass
            tmp.append("null")
            urls.append(url)
            print(url)
    print("총 {}건 중 {} 건 크롤링 성공".format(idx+1,cnt))
    data[date] = [tmp,[url]]
    date = date.replace('/','-')
    with open(main_path + '/' + 'news_backup/' + 'news-' + date + '.pickle','wb') as f:
        pickle.dump(data,f)
    print(date,' 크롤링 완료')
# Out:
# 2/14/2023 크롤링 시작
# 7it [00:08,  1.15s/it]
# https://simpleflying.com/klm-economy-berlin-amsterdam-review/
# 10it [00:10,  1.02s/it]
# 총 10건 중 9 건 크롤링 성공
# 2-14-2023  크롤링 완료

# %%
 pd.DataFrame(data).T
# Out:
#                                                            0  \
# 2/14/2023  [[Create a free account and access your person...
#
#                                                            1
# 2/14/2023  [https://www.bloomberg.com/news/articles/2023-...

# %%
data = pd.DataFrame(data).T

data = data.rename({0:"news"},axis= 1)

name = "News{}-{}.pickle".format(from_date,to_date)
name = name.replace('/','.')

with open(main_path + '/' + 'news/' + name,'wb') as f:
    pickle.dump(data,f)

# %%
with open(main_path + '/' + 'news/' + name,'wb') as f:
    pickle.dump(data,f)

# %%
from keybert import KeyBERT
import pickle
import re
from tqdm import tqdm
import pandas as pd
import os

# %%
def doc2key(cleaned_content):
    
    kw_model = KeyBERT(model='all-MiniLM-L6-v2')
    keywords = kw_model.extract_keywords(doc)
    
    n2_kwd = kw_model.extract_keywords(cleaned_content, keyphrase_ngram_range=(2, 2), stop_words='english',
                                  use_mmr=True, diversity=0.7, top_n=5)

    n1_kwd = kw_model.extract_keywords(cleaned_content, keyphrase_ngram_range=(1, 1), stop_words='english',
                                  use_mmr=True, diversity=0.7, top_n=45)
    for idx,i in enumerate(n2_kwd):
        n2_kwd[idx] = i[0]
    for idx,i in enumerate(n1_kwd):
        n1_kwd[idx] = i[0]  

    n1_kwd.extend(n2_kwd)
    kwd = n1_kwd
    return kwd

# %%
name = "News{}-{}.pickle".format(from_date,to_date)
name = name.replace('/','.')

with open(main_path + '/' + 'news/' + name, 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
#                                                         news
# 2/14/2023  [We're buying 50 more shares of Caterpillar (C...

# %%
data = data.reset_index()
data = data.rename({"index":"date"},axis = 1)

idx = []
for x in data['date']:
    tmp = x.split('/')
    if len(tmp[0]) == 1:
        tmp[0] = '0'+tmp[0]
    if len(tmp[1]) == 1:
        tmp[1] = '0'+tmp[1]
    tmp = tmp[2] + tmp[0] + tmp[1]
    idx.append(''.join(tmp))

# %%
data['date'] = idx
data = data.rename({'date':'일자'},axis = 1)

# %%
kwd_list = []
for docs in tqdm(data['news']):
    kwds = []
    for doc in tqdm(docs):
        try:
            cleaned_content = re.sub(r'[^\.\?\!\w\d\s]','',doc) # 문장단위로 끊기
            cleaned_content = cleaned_content.replace('\n',' ')
            cleaned_content = cleaned_content.lower()
            kwd = doc2key(cleaned_content)
            kwds.append(kwd)
        except:
            print(doc)
    kwd_list.append(kwds)
# Out:
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#   0%|                                                                                          | 0/205 [00:00<?, ?it/s]
#   0%|▍                                                                                 | 1/205 [00:01<04:52,  1.44s/it]
#   1%|▊                                                                                 | 2/205 [00:02<04:01,  1.19s/it]
#   1%|█▏                                                                                | 3/205 [00:03<03:25,  1.01s/it]
#   2%|█▌                                                                                | 4/205 [00:03<02:37,  1.28it/s]
#   2%|██                                                                                | 5/205 [00:04<02:19,  1.43it/s]
#   3%|██▍                                                                               | 6/205 [00:05<02:51,  1.16it/s]
#   3%|██▊                                                                               | 7/205 [00:06<02:50,  1.16it/s]
#   4%|███▏                                                                              | 8/205 [00:06<02:19,  1.42it/s]
#   4%|███▌                                                                              | 9/205 [00:07<02:23,  1.37it/s]
#   5%|███▉                                                                             | 10/205 [00:08<02:54,  1.12it/s]
#   5%|████▎                                                                            | 11/205 [00:10<03:44,  1.16s/it]
#   6%|████▋                                                                            | 12/205 [00:11<03:56,  1.23s/it]
#   6%|█████▏                                                                           | 13/205 [00:13<04:15,  1.33s/it]
#   7%|█████▌                                                                           | 14/205 [00:14<03:53,  1.23s/it]
#   7%|█████▉                                                                           | 15/205 [00:16<04:18,  1.36s/it]
#   8%|██████▎                                                                          | 16/205 [00:16<03:27,  1.10s/it]
#   8%|██████▋                                                                          | 17/205 [00:17<03:18,  1.06s/it]
#   9%|███████                                                                          | 18/205 [00:19<03:44,  1.20s/it]
#   9%|███████▌                                                                         | 19/205 [00:20<03:50,  1.24s/it]
#  10%|███████▉                                                                         | 20/205 [00:21<03:59,  1.29s/it]
#  10%|████████▎                                                                        | 21/205 [00:23<04:34,  1.49s/it]
#  11%|████████▋                                                                        | 22/205 [00:25<04:23,  1.44s/it]
#  11%|█████████                                                                        | 23/205 [00:26<04:41,  1.55s/it]
#  12%|█████████▍                                                                       | 24/205 [00:28<04:33,  1.51s/it]
#  12%|█████████▉                                                                       | 25/205 [00:28<03:40,  1.23s/it]
#  13%|██████████▎                                                                      | 26/205 [00:29<03:33,  1.19s/it]
#  13%|██████████▋                                                                      | 27/205 [00:30<02:47,  1.07it/s]
#  14%|███████████                                                                      | 28/205 [00:31<03:14,  1.10s/it]
#  14%|███████████▍                                                                     | 29/205 [00:33<03:28,  1.18s/it]
#  15%|███████████▊                                                                     | 30/205 [00:35<04:07,  1.41s/it]
#  15%|████████████▏                                                                    | 31/205 [00:36<03:45,  1.30s/it]
#  16%|████████████▋                                                                    | 32/205 [00:37<03:49,  1.33s/it]
#  16%|█████████████                                                                    | 33/205 [00:39<04:16,  1.49s/it]
#  17%|█████████████▍                                                                   | 34/205 [00:40<04:18,  1.51s/it]
#  17%|█████████████▊                                                                   | 35/205 [00:42<04:35,  1.62s/it]
#  18%|██████████████▏                                                                  | 36/205 [00:43<04:09,  1.48s/it]
#  18%|██████████████▌                                                                  | 37/205 [00:44<03:17,  1.17s/it]
#  19%|███████████████                                                                  | 38/205 [00:45<03:08,  1.13s/it]
#  19%|███████████████▍                                                                 | 39/205 [00:46<03:19,  1.20s/it]
#  20%|███████████████▊                                                                 | 40/205 [00:48<04:03,  1.47s/it]
#  20%|████████████████▏                                                                | 41/205 [00:52<05:57,  2.18s/it]
#  20%|████████████████▌                                                                | 42/205 [00:55<06:26,  2.37s/it]
#  21%|████████████████▉                                                                | 43/205 [00:57<06:21,  2.35s/it]
#  21%|█████████████████▍                                                               | 44/205 [00:58<05:10,  1.93s/it]
#  22%|█████████████████▊                                                               | 45/205 [01:00<05:11,  1.94s/it]
#  22%|██████████████████▏                                                              | 46/205 [01:01<04:20,  1.64s/it]
#  23%|██████████████████▌                                                              | 47/205 [01:03<04:17,  1.63s/it]
#  23%|██████████████████▉                                                              | 48/205 [01:06<05:17,  2.02s/it]
#  24%|███████████████████▎                                                             | 49/205 [01:10<07:03,  2.71s/it]
#  24%|███████████████████▊                                                             | 50/205 [01:13<06:57,  2.69s/it]
#  25%|████████████████████▏                                                            | 51/205 [01:14<05:34,  2.17s/it]
#  25%|████████████████████▌                                                            | 52/205 [01:18<07:07,  2.80s/it]
#  26%|████████████████████▉                                                            | 53/205 [01:21<06:54,  2.73s/it]
#  26%|█████████████████████▎                                                           | 54/205 [01:24<07:30,  2.98s/it]
#  27%|█████████████████████▋                                                           | 55/205 [01:25<06:09,  2.47s/it]
#  27%|██████████████████████▏                                                          | 56/205 [01:28<06:10,  2.49s/it]
#  28%|██████████████████████▌                                                          | 57/205 [01:31<06:28,  2.63s/it]
#  28%|██████████████████████▉                                                          | 58/205 [01:37<09:01,  3.68s/it]
#  29%|███████████████████████▎                                                         | 59/205 [01:41<09:07,  3.75s/it]
#  29%|███████████████████████▋                                                         | 60/205 [01:42<07:25,  3.07s/it]
#  30%|████████████████████████                                                         | 61/205 [01:45<07:07,  2.97s/it]
#  30%|████████████████████████▍                                                        | 62/205 [01:48<06:56,  2.91s/it]
#  31%|████████████████████████▉                                                        | 63/205 [01:52<07:25,  3.14s/it]
#  31%|█████████████████████████▎                                                       | 64/205 [01:53<06:06,  2.60s/it]
#  32%|█████████████████████████▋                                                       | 65/205 [01:56<06:16,  2.69s/it]
#  32%|██████████████████████████                                                       | 66/205 [01:59<06:33,  2.83s/it]
#  33%|██████████████████████████▍                                                      | 67/205 [02:00<05:19,  2.32s/it]
#  34%|███████████████████████████▎                                                     | 69/205 [03:05<33:51, 14.94s/it]
#  34%|███████████████████████████▋                                                     | 70/205 [03:06<24:27, 10.87s/it]
#  35%|████████████████████████████                                                     | 71/205 [03:09<18:36,  8.33s/it]
#  35%|████████████████████████████▍                                                    | 72/205 [03:12<15:26,  6.97s/it]
#  36%|████████████████████████████▊                                                    | 73/205 [03:16<12:53,  5.86s/it]
#  36%|█████████████████████████████▏                                                   | 74/205 [03:20<11:42,  5.36s/it]
#  37%|█████████████████████████████▋                                                   | 75/205 [03:23<10:11,  4.70s/it]
#  37%|██████████████████████████████                                                   | 76/205 [03:26<09:12,  4.28s/it]
#  38%|██████████████████████████████▍                                                  | 77/205 [03:28<07:14,  3.40s/it]
#  38%|██████████████████████████████▊                                                  | 78/205 [04:18<37:06, 17.53s/it]
#  39%|███████████████████████████████▏                                                 | 79/205 [04:19<26:18, 12.53s/it]
#  39%|███████████████████████████████▌                                                 | 80/205 [04:22<20:02,  9.62s/it]
#  40%|████████████████████████████████▊                                                | 83/205 [05:50<33:21, 16.41s/it]
#  41%|█████████████████████████████████▏                                               | 84/205 [05:51<23:46, 11.79s/it]
#  41%|█████████████████████████████████▌                                               | 85/205 [05:52<17:09,  8.58s/it]
#  42%|█████████████████████████████████▉                                               | 86/205 [05:52<12:11,  6.14s/it]
#  42%|██████████████████████████████████▍                                              | 87/205 [05:58<11:32,  5.87s/it]
#  43%|██████████████████████████████████▊                                              | 88/205 [06:02<10:40,  5.47s/it]
#  43%|███████████████████████████████████▏                                             | 89/205 [06:04<08:40,  4.49s/it]
#  44%|███████████████████████████████████▌                                             | 90/205 [06:05<06:31,  3.41s/it]
#  44%|███████████████████████████████████▉                                             | 91/205 [06:09<06:45,  3.56s/it]
#  45%|████████████████████████████████████▎                                            | 92/205 [06:12<06:06,  3.24s/it]
#  45%|████████████████████████████████████▋                                            | 93/205 [06:12<04:35,  2.46s/it]
#  46%|█████████████████████████████████████▏                                           | 94/205 [06:15<04:28,  2.41s/it]
#  46%|█████████████████████████████████████▌                                           | 95/205 [06:19<05:27,  2.98s/it]
#  47%|█████████████████████████████████████▉                                           | 96/205 [06:24<06:20,  3.49s/it]
#  47%|██████████████████████████████████████▎                                          | 97/205 [06:27<06:17,  3.50s/it]
#  48%|██████████████████████████████████████▋                                          | 98/205 [06:31<06:19,  3.55s/it]
#  48%|███████████████████████████████████████                                          | 99/205 [06:34<06:02,  3.42s/it]
#  49%|███████████████████████████████████████                                         | 100/205 [06:39<06:46,  3.87s/it]
#  49%|███████████████████████████████████████▍                                        | 101/205 [06:39<05:01,  2.90s/it]
#  50%|███████████████████████████████████████▊                                        | 102/205 [06:43<05:25,  3.16s/it]
#  50%|████████████████████████████████████████▏                                       | 103/205 [06:48<06:20,  3.73s/it]
#  51%|████████████████████████████████████████▌                                       | 104/205 [06:52<06:02,  3.59s/it]
#  51%|████████████████████████████████████████▉                                       | 105/205 [06:52<04:36,  2.77s/it]
#  52%|█████████████████████████████████████████▎                                      | 106/205 [06:55<04:28,  2.72s/it]
#  52%|█████████████████████████████████████████▊                                      | 107/205 [07:00<05:46,  3.53s/it]
#  53%|██████████████████████████████████████████▏                                     | 108/205 [07:01<04:17,  2.66s/it]
#  53%|██████████████████████████████████████████▌                                     | 109/205 [07:03<04:07,  2.58s/it]
#  54%|██████████████████████████████████████████▉                                     | 110/205 [07:07<04:26,  2.81s/it]
#  54%|███████████████████████████████████████████▎                                    | 111/205 [07:10<04:20,  2.78s/it]
#  55%|███████████████████████████████████████████▋                                    | 112/205 [07:12<04:18,  2.78s/it]
#  55%|████████████████████████████████████████████                                    | 113/205 [07:14<03:53,  2.54s/it]
#  56%|████████████████████████████████████████████▍                                   | 114/205 [07:22<06:18,  4.16s/it]
#  56%|████████████████████████████████████████████▉                                   | 115/205 [07:25<05:34,  3.72s/it]
#  57%|█████████████████████████████████████████████▎                                  | 116/205 [07:26<04:20,  2.92s/it]
#  57%|█████████████████████████████████████████████▋                                  | 117/205 [07:29<04:30,  3.08s/it]
#  58%|██████████████████████████████████████████████                                  | 118/205 [07:32<04:26,  3.06s/it]
#  58%|██████████████████████████████████████████████▍                                 | 119/205 [07:35<04:19,  3.02s/it]
#  59%|██████████████████████████████████████████████▊                                 | 120/205 [07:38<03:57,  2.79s/it]
#  59%|███████████████████████████████████████████████▏                                | 121/205 [07:38<02:59,  2.14s/it]
#  60%|███████████████████████████████████████████████▌                                | 122/205 [07:42<03:29,  2.52s/it]
#  60%|████████████████████████████████████████████████                                | 123/205 [07:45<03:38,  2.66s/it]
#  60%|████████████████████████████████████████████████▍                               | 124/205 [07:48<03:52,  2.87s/it]
#  61%|████████████████████████████████████████████████▊                               | 125/205 [07:49<03:05,  2.32s/it]
#  61%|█████████████████████████████████████████████████▏                              | 126/205 [07:52<03:10,  2.41s/it]
#  62%|█████████████████████████████████████████████████▌                              | 127/205 [07:54<03:07,  2.41s/it]
#  62%|█████████████████████████████████████████████████▉                              | 128/205 [07:56<03:05,  2.41s/it]
#  63%|██████████████████████████████████████████████████▎                             | 129/205 [07:57<02:30,  1.97s/it]
#  63%|██████████████████████████████████████████████████▋                             | 130/205 [08:00<02:47,  2.24s/it]
#  64%|███████████████████████████████████████████████████                             | 131/205 [08:02<02:44,  2.22s/it]
#  64%|███████████████████████████████████████████████████▌                            | 132/205 [08:08<03:44,  3.07s/it]
#  65%|███████████████████████████████████████████████████▉                            | 133/205 [08:11<03:40,  3.06s/it]
#  65%|████████████████████████████████████████████████████▎                           | 134/205 [08:14<03:55,  3.32s/it]
#  66%|████████████████████████████████████████████████████▋                           | 135/205 [08:16<03:20,  2.87s/it]
#  66%|█████████████████████████████████████████████████████                           | 136/205 [08:19<03:14,  2.81s/it]
#  67%|█████████████████████████████████████████████████████▍                          | 137/205 [08:23<03:29,  3.08s/it]
#  67%|█████████████████████████████████████████████████████▊                          | 138/205 [08:25<03:14,  2.91s/it]
#  68%|██████████████████████████████████████████████████████▏                         | 139/205 [08:27<02:51,  2.60s/it]
#  68%|██████████████████████████████████████████████████████▋                         | 140/205 [08:30<02:58,  2.74s/it]
#  69%|███████████████████████████████████████████████████████                         | 141/205 [08:32<02:43,  2.55s/it]
#  69%|███████████████████████████████████████████████████████▍                        | 142/205 [08:35<02:40,  2.55s/it]
#  70%|███████████████████████████████████████████████████████▊                        | 143/205 [08:37<02:34,  2.50s/it]
#  70%|████████████████████████████████████████████████████████▏                       | 144/205 [08:41<02:52,  2.83s/it]
#  71%|████████████████████████████████████████████████████████▌                       | 145/205 [08:44<03:02,  3.04s/it]
#  71%|████████████████████████████████████████████████████████▉                       | 146/205 [08:48<03:13,  3.27s/it]
#  72%|█████████████████████████████████████████████████████████▎                      | 147/205 [08:51<03:07,  3.24s/it]
#  72%|█████████████████████████████████████████████████████████▊                      | 148/205 [08:57<03:51,  4.06s/it]
#  73%|██████████████████████████████████████████████████████████▏                     | 149/205 [08:58<02:50,  3.04s/it]
#  73%|██████████████████████████████████████████████████████████▌                     | 150/205 [09:00<02:23,  2.62s/it]
#  74%|██████████████████████████████████████████████████████████▉                     | 151/205 [09:02<02:15,  2.51s/it]
#  74%|███████████████████████████████████████████████████████████▎                    | 152/205 [09:04<02:08,  2.43s/it]
#  75%|███████████████████████████████████████████████████████████▋                    | 153/205 [09:09<02:46,  3.20s/it]
#  75%|████████████████████████████████████████████████████████████                    | 154/205 [09:18<04:09,  4.89s/it]
#  76%|████████████████████████████████████████████████████████████▍                   | 155/205 [09:21<03:44,  4.49s/it]
#  76%|████████████████████████████████████████████████████████████▉                   | 156/205 [09:23<02:50,  3.48s/it]
#  77%|█████████████████████████████████████████████████████████████▎                  | 157/205 [09:27<02:59,  3.73s/it]
#  77%|█████████████████████████████████████████████████████████████▋                  | 158/205 [09:30<02:48,  3.59s/it]
#  78%|██████████████████████████████████████████████████████████████                  | 159/205 [09:31<02:06,  2.75s/it]
#  78%|██████████████████████████████████████████████████████████████▍                 | 160/205 [09:38<02:59,  3.98s/it]
#  79%|██████████████████████████████████████████████████████████████▊                 | 161/205 [09:41<02:51,  3.89s/it]
#  79%|███████████████████████████████████████████████████████████████▏                | 162/205 [09:47<03:10,  4.43s/it]
#  80%|███████████████████████████████████████████████████████████████▌                | 163/205 [09:50<02:42,  3.88s/it]
#  80%|████████████████████████████████████████████████████████████████                | 164/205 [09:55<02:54,  4.26s/it]
#  80%|████████████████████████████████████████████████████████████████▍               | 165/205 [09:59<02:45,  4.15s/it]
#  81%|████████████████████████████████████████████████████████████████▊               | 166/205 [10:09<03:54,  6.01s/it]
#  81%|█████████████████████████████████████████████████████████████████▏              | 167/205 [10:16<04:02,  6.39s/it]
#  82%|█████████████████████████████████████████████████████████████████▌              | 168/205 [10:31<05:31,  8.95s/it]
#  82%|█████████████████████████████████████████████████████████████████▉              | 169/205 [10:34<04:13,  7.05s/it]
#  83%|██████████████████████████████████████████████████████████████████▎             | 170/205 [10:35<03:01,  5.20s/it]
#  83%|██████████████████████████████████████████████████████████████████▋             | 171/205 [10:38<02:39,  4.69s/it]
#  84%|███████████████████████████████████████████████████████████████████             | 172/205 [10:39<01:54,  3.47s/it]
#  84%|███████████████████████████████████████████████████████████████████▌            | 173/205 [10:41<01:36,  3.01s/it]
#  85%|███████████████████████████████████████████████████████████████████▉            | 174/205 [10:43<01:28,  2.87s/it]
#  85%|████████████████████████████████████████████████████████████████████▎           | 175/205 [10:46<01:26,  2.88s/it]
#  86%|████████████████████████████████████████████████████████████████████▋           | 176/205 [10:49<01:23,  2.89s/it]
#  86%|█████████████████████████████████████████████████████████████████████           | 177/205 [10:52<01:21,  2.92s/it]
#  87%|█████████████████████████████████████████████████████████████████████▍          | 178/205 [10:54<01:10,  2.62s/it]
#  87%|█████████████████████████████████████████████████████████████████████▊          | 179/205 [10:58<01:16,  2.94s/it]
#  88%|██████████████████████████████████████████████████████████████████████▏         | 180/205 [11:01<01:16,  3.07s/it]
#  88%|██████████████████████████████████████████████████████████████████████▋         | 181/205 [11:06<01:27,  3.63s/it]
#  89%|███████████████████████████████████████████████████████████████████████         | 182/205 [11:10<01:22,  3.58s/it]
#  89%|███████████████████████████████████████████████████████████████████████▍        | 183/205 [11:13<01:19,  3.64s/it]
#  90%|███████████████████████████████████████████████████████████████████████▊        | 184/205 [11:18<01:24,  4.02s/it]
#  90%|████████████████████████████████████████████████████████████████████████▏       | 185/205 [11:21<01:12,  3.63s/it]
#  91%|████████████████████████████████████████████████████████████████████████▌       | 186/205 [11:24<01:05,  3.44s/it]
#  91%|████████████████████████████████████████████████████████████████████████▉       | 187/205 [11:29<01:09,  3.86s/it]
#  92%|█████████████████████████████████████████████████████████████████████████▎      | 188/205 [11:31<00:59,  3.49s/it]
#  92%|█████████████████████████████████████████████████████████████████████████▊      | 189/205 [11:34<00:53,  3.33s/it]
#  93%|██████████████████████████████████████████████████████████████████████████▏     | 190/205 [11:37<00:44,  2.99s/it]
#  93%|██████████████████████████████████████████████████████████████████████████▌     | 191/205 [11:38<00:33,  2.41s/it]
#  94%|██████████████████████████████████████████████████████████████████████████▉     | 192/205 [11:41<00:36,  2.80s/it]
#  94%|███████████████████████████████████████████████████████████████████████████▎    | 193/205 [11:44<00:31,  2.61s/it]
#  95%|███████████████████████████████████████████████████████████████████████████▋    | 194/205 [11:44<00:22,  2.07s/it]
#  95%|████████████████████████████████████████████████████████████████████████████    | 195/205 [11:48<00:25,  2.56s/it]
#  96%|████████████████████████████████████████████████████████████████████████████▍   | 196/205 [11:49<00:18,  2.05s/it]
#  96%|████████████████████████████████████████████████████████████████████████████▉   | 197/205 [11:51<00:16,  2.10s/it]
#  97%|█████████████████████████████████████████████████████████████████████████████▎  | 198/205 [11:52<00:12,  1.74s/it]
#  97%|█████████████████████████████████████████████████████████████████████████████▋  | 199/205 [11:55<00:12,  2.16s/it]
#  98%|██████████████████████████████████████████████████████████████████████████████  | 200/205 [12:00<00:14,  2.84s/it]
#  98%|██████████████████████████████████████████████████████████████████████████████▍ | 201/205 [12:04<00:12,  3.22s/it]
#  99%|██████████████████████████████████████████████████████████████████████████████▊ | 202/205 [12:06<00:08,  2.95s/it]
#  99%|███████████████████████████████████████████████████████████████████████████████▏| 203/205 [12:09<00:05,  2.91s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████▌| 204/205 [12:13<00:03,  3.21s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 205/205 [12:17<00:00,  3.60s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [12:17<00:00, 737.73s/it]

# %%
data['kwd'] = kwd_list

# %%
## 하루를 가정하고 만듬 -> 여러날에도 가능하게 수정 필요
kwd_nn_jj_list = []

for news in kwd_list[0]:
    tokens_pos = nltk.pos_tag(news)
    words = []
    for word, pos in tokens_pos:
        if 'NN' in pos or 'JJ' in pos:
            words.append(word)
    kwd_nn_jj_list.append(words)

# %%
kwd_list[0] = kwd_nn_jj_list

# %%
data['kwd'] = kwd_list

# %%
name = "Keyword{}-{}.pickle".format(from_date,to_date)
name = name.replace('/','.')
with open(main_path + '/' + 'keyword/' + name,'wb') as f:
    pickle.dump(data,f)

# %%
data['kwd'][0]
# Out:
# [['caterpillar',
#   'earnings',
#   'diversified',
#   'cramers',
#   'pricecost',
#   'pushbacks',
#   'performance',
#   'pivot',
#   'baird',
#   'trusts',
#   'major',
#   'expectations',
#   'industrials',
#   'drives',
#   'cyclical',
#   'tailwinds',
#   'bearish',
#   'monday',
#   'waits',
#   'longterm',
#   'havent',
#   'receipt',
#   'factors',
#   'downgraded',
#   'street',
#   'disclaimer',
#   'afp',
#   'shares caterpillar',
#   'cat believes',
#   'outperformance baird',
#   'qcom list'],
#  ['recession',
#   'goldman',
#   'capital',
#   'sector',
#   'hope',
#   'solomon',
#   'sentiment',
#   'advisors',
#   'soft',
#   'january',
#   'wef',
#   'steep',
#   'uncertainty',
#   'consensus',
#   'drop',
#   'miami',
#   'secondever',
#   'hes',
#   'elusive',
#   'acquisitions',
#   'resilient',
#   'cautioned',
#   'index',
#   'suisse',
#   'feeding',
#   'department',
#   'initial',
#   'bar',
#   'basis',
#   'mirror',
#   'worlds',
#   'dovish',
#   'workers',
#   'navigate',
#   'deterrent',
#   'recession result',
#   'market sense',
#   'chairman ceo',
#   'stick elusive'],
#  ['premium',
#   'subscription',
#   'trial',
#   'access',
#   'digital',
#   'cost',
#   'savings',
#   'premier',
#   'plan',
#   'month',
#   'downgrade',
#   'opt',
#   'settings',
#   'standard',
#   'cancel',
#   'lex',
#   'reporting',
#   'business',
#   'retain',
#   'section',
#   'journalistic',
#   'offering',
#   'click',
#   'comparison',
#   'packages',
#   'themes',
#   'expert',
#   'column',
#   'original',
#   'robust',
#   'fulfils',
#   'digital premium',
#   'trial trial',
#   'change plan',
#   'retain access',
#   'news analysis'],
#  ['geothermal',
#   'biofuel',
#   'farmland',
#   'methane',
#   'emissions',
#   'energy',
#   'economy',
#   'food',
#   'global',
#   'crises',
#   'hours',
#   'use geothermal',
#   'grow biofuel',
#   'instead food',
#   'ago 13',
#   'economy mercy'],
#  ['economic',
#   'international',
#   'world',
#   'article',
#   'analyses',
#   'commons',
#   'free',
#   'forum',
#   'account',
#   'terms',
#   'public',
#   'accordance',
#   'create',
#   'publications',
#   'views',
#   'content',
#   'license',
#   'creative',
#   'access',
#   'latest',
#   'collection',
#   'author',
#   'world economic',
#   'free account',
#   'publications analyses'],
#  ['recession',
#   'gdp',
#   'forecast',
#   'investable',
#   'sachs',
#   'grow',
#   'insights',
#   'briggs',
#   'institutional',
#   'backing',
#   'universe',
#   'demandcould',
#   'evergrande',
#   'etfs',
#   'expectations',
#   'index',
#   'particular',
#   'recovery',
#   'upgrade',
#   'end',
#   'hotels',
#   'topdown',
#   'pace',
#   'real',
#   'ldrs',
#   'avenues',
#   'willing',
#   'dutyfree',
#   'kraneshares',
#   'devesh',
#   'basis',
#   'csi',
#   'couple',
#   'recession china',
#   'funds etfs',
#   'fasterthanexpected rate',
#   'takes smart'],
#  ['fiscal',
#   'singaporeans',
#   'inflation',
#   'sustainable',
#   'minister',
#   'cost',
#   'cope',
#   'estimate',
#   'measures',
#   's3',
#   'pressures',
#   'foreign',
#   'weak',
#   'fuel',
#   'soong',
#   'precovid',
#   'prudence',
#   'recent',
#   'delicate',
#   'slight',
#   'squawk',
#   'try',
#   'day',
#   'interview',
#   'cnbcs',
#   'lawrence',
#   'hand',
#   'thats',
#   'push',
#   'levels',
#   'hikes',
#   'balancing act',
#   'year 2022',
#   'recovered precovid'],
#  ['browser',
#   'javascript',
#   'cookies',
#   'service',
#   'supports',
#   'review',
#   'policy',
#   'terms',
#   'information',
#   'happen',
#   'sure',
#   'supports javascript',
#   'loading information',
#   'did happen',
#   'review terms'],
#  ['gdp',
#   'growth',
#   'forecasting',
#   'increase',
#   'budget',
#   'advances',
#   'yearonyear',
#   'q4',
#   'projections',
#   'domestic',
#   'statistics',
#   'previous',
#   'report',
#   'series',
#   'official',
#   'product',
#   'quarter',
#   'source',
#   'state',
#   'natanael',
#   'maricaromaniainsider',
#   'tuesday',
#   'ec',
#   'commission',
#   'com',
#   'vs',
#   'body',
#   'gross',
#   'flash',
#   'romanias gdp',
#   'yearonyear growth',
#   'q4 2022',
#   'body cnp'],
#  ['mauritanias',
#   'disasters',
#   'populations',
#   'growth',
#   'economist',
#   'households',
#   'initiatives',
#   'electricity',
#   'costs',
#   'poorest',
#   'capita',
#   'land',
#   'mediumterm',
#   'women',
#   'data',
#   'onefourth',
#   'insecurity',
#   'imfs',
#   'coverage',
#   'jarin',
#   'department',
#   'average',
#   'return',
#   'anta',
#   'natural',
#   'sooner',
#   'ozlu',
#   'significant',
#   'onur',
#   'limit',
#   'tubewell',
#   'buffer',
#   'longstanding',
#   'central',
#   'mauritanias growth',
#   'disasters economy',
#   'droughtrelated effect',
#   'electricity percent',
#   'health coverage'],
#  ['inflation',
#   'forecasts',
#   'bond',
#   'barclays',
#   'sachs',
#   'consumer',
#   'tuesdays',
#   'pessimistic',
#   'strategists',
#   'theyve',
#   'federal',
#   'soft',
#   'turnaround',
#   'fargo',
#   'stay',
#   'plc',
#   'bears',
#   'intensify',
#   'macro',
#   'view',
#   'recovery',
#   'start',
#   'hikes',
#   'implies',
#   'periods',
#   'dovish',
#   'shortdollar',
#   'emmanuel',
#   'latest inflation',
#   'plc strategists',
#   'risk appetite',
#   'positions retreat'],
#  ['inflation',
#   'slowdown',
#   'trend',
#   'fuel',
#   'pace',
#   'rate',
#   'customers',
#   'expensive',
#   'borrowing',
#   'bulk',
#   'factor',
#   'months',
#   'high',
#   'news',
#   'benchmark',
#   'target',
#   'readings',
#   'pressures',
#   'administrations',
#   'sector',
#   'salaries',
#   'americans',
#   'laborintensive',
#   'tuesdays',
#   'average',
#   'hike',
#   'foresees',
#   'categories',
#   'standoff',
#   'basis',
#   'openings',
#   'englishlanguage',
#   'país',
#   'slowdown inflation',
#   'fuel price',
#   'december january',
#   'food clothing',
#   'report government'],
#  ['summit',
#   'global',
#   'humanitarian',
#   'economist',
#   'presidents',
#   'future',
#   'arab',
#   'health',
#   'climate',
#   'diversification',
#   'experts',
#   'imf',
#   'heads',
#   'topics',
#   'talk',
#   'elsisi',
#   'priority',
#   'merchandise',
#   'fiscal',
#   'propose',
#   'resilience',
#   'cop28',
#   'glimmers',
#   'artificial',
#   'belong',
#   'arbitration',
#   'fattah',
#   'coronavirus',
#   'build',
#   'banner',
#   'alleviate',
#   'fields',
#   'monday',
#   'governments summit',
#   'change health',
#   'added imf',
#   'dispute arbitration'],
#  ['bangkok',
#   'inflationary',
#   'fiscal',
#   'investment',
#   'tourism',
#   'sector',
#   'forecast',
#   'baht',
#   'kitiphong',
#   'policy',
#   'reuters',
#   'bank',
#   'reduces',
#   'key',
#   'recovery',
#   'termpittayapaisith',
#   'asian',
#   'review',
#   'costs',
#   'hike',
#   'minister',
#   'cycle',
#   'march',
#   'staporncharnchai',
#   'grow',
#   'orathai',
#   'pressures',
#   'contain',
#   'arkhom',
#   'expect',
#   'petty',
#   'forum',
#   'standards',
#   'peers',
#   'gradual rate',
#   'hike reporting',
#   'accommodative does'],
#  ['florists',
#   'market',
#   'yuan',
#   'asias',
#   'qian',
#   'province',
#   'spice',
#   'parcels',
#   'shenchong',
#   'agricultural',
#   'yuyong',
#   'fullcargo',
#   'lifecycle',
#   'preferences',
#   'refrigeration',
#   'unimaginable',
#   'fields',
#   'postharvest',
#   'hours',
#   'branch',
#   'little',
#   'confidence',
#   'average',
#   'patterns',
#   'standardized',
#   'centers',
#   'birthdays',
#   'pandemic',
#   'lin',
#   'refuse',
#   'highquality',
#   'requirements',
#   'high freshcut',
#   'said chen'],
#  ['cpi',
#   'economy',
#   'feds',
#   'power',
#   'sethi',
#   'data',
#   'strong',
#   'sarat',
#   'twitter',
#   'article',
#   'number',
#   'look',
#   'share',
#   'lunch',
#   'sees',
#   'linkedin',
#   'path',
#   'discuss',
#   'economy strong',
#   'hotterthanexpected cpi',
#   'sethi dclas',
#   'sees feds'],
#  ['economy',
#   'cost',
#   'inflationary',
#   'importers',
#   'barriers',
#   'travel',
#   'sustainable',
#   'pandemic',
#   'global',
#   'leveraging',
#   'oecd',
#   'ukraine',
#   'consequences',
#   'secretarygeneral',
#   'trade',
#   'organization',
#   'cormann',
#   'commitments',
#   'index',
#   'measures',
#   'recovery',
#   'uncertainty',
#   'average',
#   'control',
#   'factor',
#   'pressures',
#   'audiovisual',
#   'avenues',
#   'times',
#   'fresh',
#   'mathias',
#   'joint',
#   'global economic',
#   'services oecd',
#   'barriers limits',
#   'audiovisual computer'],
#  ['manufacturers',
#   'quarterly',
#   'recession',
#   'confidence',
#   'sectorial',
#   'factors',
#   'deterioration',
#   'naira',
#   'index',
#   'improvement',
#   'environment',
#   'challenges',
#   'wage',
#   'policies',
#   'insufficient',
#   'membercompanies',
#   'macroeconomy',
#   'measures',
#   'imagine',
#   'operators',
#   'current',
#   'benchmark',
#   'underlined',
#   'unpredictability',
#   'pulse',
#   'diffusion',
#   'capitals',
#   'russianukrainian',
#   'persisting',
#   'tuesday',
#   'base',
#   'nigerian economy',
#   'manufacturers confidence',
#   'points decline',
#   'pulse operators'],
#  ['productivity',
#   'gdp',
#   'slowdown',
#   'england',
#   'reforms',
#   'sectors',
#   'haskels',
#   'reduction',
#   'overshoot',
#   'pandemic',
#   'jonathan',
#   'think',
#   'tracks',
#   'unsettled',
#   'spokeswoman',
#   'g7',
#   'evidence',
#   'cost',
#   'domestic',
#   'extreme',
#   'hannah',
#   'grow',
#   'mckayreuters',
#   'newsletter',
#   'freedoms',
#   'utc',
#   'probrexit',
#   'protocol',
#   'brexit productivity',
#   'dropped g7',
#   'hannah mckayreuters'],
#  ['gdp',
#   'recession',
#   'dutch',
#   'rates',
#   'average',
#   'increase',
#   'downturn',
#   'quarters',
#   'energy',
#   'household',
#   'consecutive',
#   'report',
#   'wouldve',
#   'factored',
#   'transportation',
#   'secondhighest',
#   'thumb',
#   'reveal',
#   'figures',
#   'unsurprising',
#   'neighbouring',
#   'little',
#   'morning',
#   'mulligen',
#   'hein',
#   'cbs',
#   'com',
#   'bloc',
#   'minhanphotos',
#   'recession netherlands',
#   'cbs growth',
#   'percent average',
#   'thumb minhanphotos'],
#  ['navy',
#   'newport',
#   'nuwcnewport',
#   'expenditures',
#   'division',
#   'undersea',
#   'logistics',
#   'fishers',
#   'percent',
#   'technical',
#   'base',
#   'addition',
#   'superiority',
#   'prekindergarten',
#   'gross',
#   'capital',
#   'agreements',
#   'linkedin',
#   'palm',
#   'life',
#   'dodge',
#   'vien',
#   'httpswww',
#   'oldest',
#   'view',
#   'ron',
#   'newport employees',
#   'degree programs'],
#  ['dhabi',
#   'growth',
#   'sectors',
#   'industrial',
#   'dirhams',
#   'agile',
#   'diversify',
#   'exports',
#   'attract',
#   'accounting',
#   'nonoil',
#   'exponential',
#   'retail',
#   'domestic',
#   'data',
#   'yearonyear',
#   'fastest',
#   'real',
#   'private',
#   'policies',
#   'robust',
#   'basis',
#   'superiority',
#   'gross',
#   'north',
#   'waterfront',
#   'guests',
#   'dhabis economy',
#   'growth nonoil',
#   'passenger volumes'],
#  ['inflation',
#   'recession',
#   'pessimism',
#   'future',
#   'interpretations',
#   'jobmarket',
#   'interests',
#   'listen',
#   'pace',
#   'causal',
#   'lend',
#   'usedcar',
#   'january',
#   'weather',
#   'developments',
#   'people',
#   'fact',
#   'numbers',
#   'sticky',
#   'squint',
#   'partisans',
#   'sure',
#   'cacophony',
#   'postcovid',
#   'theyre',
#   'giftoutline',
#   'default',
#   'recovery',
#   'tea',
#   'directions',
#   'datapoints',
#   'measures',
#   'ukraine',
#   'worried inflation',
#   'construct narrative',
#   'times worst',
#   'giftoutline gift',
#   'tea leaves'],
#  ['recession',
#   'gdp',
#   'forecast',
#   'virovacz',
#   'reuters',
#   'banks',
#   'rates',
#   'quarter',
#   'slowdown',
#   'szakacs',
#   'soften',
#   'qq',
#   'expansion',
#   'second',
#   'gross',
#   'cycles',
#   'ilie',
#   'unions',
#   'january',
#   'luiza',
#   'electricity',
#   'pressures',
#   'domestic',
#   'necessarily',
#   'recovery',
#   'risks',
#   'hovetthomsonreuters',
#   'views',
#   'signs',
#   'friday',
#   'east',
#   'precrisis',
#   'com',
#   'basis',
#   'electricity prices'],
#  ['tunisians',
#   'economy',
#   'inflation',
#   'economic',
#   'living',
#   'crisis',
#   'drop',
#   'salaries',
#   'prices',
#   'governments',
#   'low',
#   'standards',
#   'faith',
#   'laurent',
#   'soar',
#   'rescue',
#   'standard',
#   'recent',
#   'years',
#   'brunt',
#   'ability',
#   'berstecher',
#   'tunisia economy',
#   'low salaries',
#   'berstecher explains'],
#  ['iclei',
#   'sustainable',
#   'initiatives',
#   'berlins',
#   'climate',
#   'agreement',
#   'international',
#   'solar',
#   'economy',
#   'circular',
#   'universities',
#   'green',
#   'co2',
#   'hwr',
#   'reductions',
#   'participants',
#   'mobility',
#   'democrats',
#   'measures',
#   'law',
#   'neutral',
#   'commits',
#   'social',
#   'forum',
#   'significant',
#   'shares',
#   'materials',
#   'experience',
#   'spaces',
#   'tons',
#   'doover',
#   'yesterday',
#   'iclei iclei',
#   'berlin school',
#   'efficiency infrastructure',
#   'adding roof'],
#  [],
#  ['massachusetts',
#   'workforce',
#   'boomers',
#   'commonwealth',
#   'estimates',
#   'ceo',
#   'massreconnect',
#   'degree',
#   'rents',
#   'regan',
#   'benefits',
#   'transition',
#   'base',
#   'students',
#   'visas',
#   'mitigate',
#   'rates',
#   'concentration',
#   'head',
#   'climates',
#   'tax',
#   'meet',
#   'launching',
#   'attractive',
#   'draws',
#   'healeys',
#   'highskilled',
#   'recent',
#   'tuesday',
#   'inclusive',
#   'added',
#   'methods',
#   'takeda said'],
#  ['inflation',
#   'economist',
#   'bank',
#   'kishida',
#   'forecasts',
#   'japans',
#   'governor',
#   'fumio',
#   'ueda',
#   'pace',
#   'sustainable',
#   'boost',
#   'pandemic',
#   'largest',
#   'framework',
#   'factors',
#   'bonds',
#   'jesper',
#   'mr',
#   'bad',
#   'potential',
#   'data',
#   'direct',
#   'moodys',
#   'try',
#   'deal',
#   'hypothesis',
#   'pragmatist',
#   'curve',
#   'dogma',
#   'returns',
#   'surfaced',
#   'months',
#   'stranger',
#   'recovering pandemic',
#   'minister names',
#   'shoot hip'],
#  ['extinction',
#   'impacts',
#   'earth',
#   'naturepositive',
#   'floodplains',
#   'mammals',
#   'renewable',
#   'planetcompatible',
#   'summit',
#   'cop15',
#   'densification',
#   'stop',
#   'flora',
#   'montreal',
#   'secretarygeneral',
#   'developments',
#   'trips',
#   'chance',
#   'refers',
#   'guterres',
#   'surfaces',
#   'assessment',
#   'pipelines',
#   'common',
#   'theres',
#   'dependence',
#   'forums',
#   'sensors',
#   'true',
#   'higherdensity',
#   'outlook',
#   'stark',
#   'reduce biodiversity',
#   'conference time',
#   'warning risks'],
#  ['consumption',
#   'market',
#   'sweets',
#   'trend',
#   'finnish',
#   'cosmetics',
#   'sok',
#   'hannu',
#   'krook',
#   'euros',
#   'vegetables',
#   'alternatives',
#   'wings',
#   'uptick',
#   'fresh',
#   'impulse',
#   'hotel',
#   'executive',
#   'uncertainty',
#   'life',
#   'categories',
#   'times',
#   'group',
#   'visible',
#   'erosion',
#   'recovery',
#   'didnt',
#   'broadcaster',
#   'monday',
#   'finnish consumers',
#   'increase slowdown',
#   'executive sok',
#   'expensive fillets'],
#  ['retirement',
#   'employeecentric',
#   'benefits',
#   'personalization',
#   'icon',
#   'plan',
#   'factors',
#   'designs',
#   'portable',
#   'consumer',
#   'participate',
#   'turnover',
#   'rowley',
#   'recent',
#   'bonus',
#   'asppa',
#   'stresses',
#   'measures',
#   'similarity',
#   'increases',
#   'bureau',
#   'interview',
#   'shortterm',
#   'multimedia',
#   'privatesector',
#   'calsavers',
#   'anticipates',
#   'subgroup',
#   's_____',
#   'population',
#   'carve',
#   'illinois',
#   'employeecentric retirement',
#   'icon attributes',
#   'think participants',
#   'shortterm factors'],
#  ['inflation',
#   'shelter',
#   'index',
#   'seasonal',
#   'energy',
#   'recent',
#   'restaurants',
#   'items',
#   'anecdotal',
#   'pandemic',
#   'percentage',
#   'core',
#   'feds',
#   'fewer',
#   'mortgage',
#   'lag',
#   'volatile',
#   'ease',
#   'start',
#   'heels',
#   'real',
#   'downshift',
#   'mls',
#   'largest',
#   'dunkelberg',
#   'likelihood',
#   'basis',
#   'person',
#   'insistent',
#   'outlook',
#   'cynical',
#   'axa',
#   'return',
#   'quarterpoint',
#   'chester',
#   'sturtevant',
#   'stages',
#   'january inflation',
#   'said week',
#   'consumer confidence'],
#  ['indonesia',
#   'recession',
#   'gdp',
#   'growth',
#   'savings',
#   'depreciation',
#   'consumers',
#   'sector',
#   'surpluses',
#   'tradable',
#   'global',
#   'habits',
#   'prices',
#   'windfall',
#   'pentup',
#   'hotels',
#   'current',
#   'buffer',
#   'export',
#   'headline',
#   'month',
#   'accelerate',
#   'vulnerable',
#   'pressures',
#   'worst',
#   'averaged',
#   'drivers',
#   'underscores',
#   'structures',
#   'avoid recession',
#   'consumption percent',
#   'distorting effect',
#   'imports drag'],
#  ['lithium',
#   'batterysafety',
#   'morefireresistant',
#   'electrochemical',
#   'nevadas',
#   'rechargeable',
#   'risk',
#   'supercapacitors',
#   'anodes',
#   'bromine',
#   'innovation',
#   'polymers',
#   'laboratorytomarket',
#   'lightest',
#   'laptops',
#   'border',
#   'likely',
#   'real',
#   'aware',
#   'harkawat',
#   'retard',
#   'focus',
#   'quantum',
#   'months',
#   'senior',
#   'modest',
#   'startup',
#   'separators',
#   'table',
#   'karsten',
#   'stages',
#   'nevadas lithium',
#   'battery adoption',
#   'office economic',
#   'preseed stage'],
#  ['inflation',
#   'sydney',
#   'cash',
#   'mortgage',
#   'pace',
#   'rba',
#   'possibility',
#   'gains',
#   'employers',
#   'resourcerich',
#   'chalmers',
#   'evidence',
#   'lowest',
#   'surge',
#   'midseptember',
#   'soft',
#   'senate',
#   'biggest',
#   'anchored',
#   'basis',
#   'risks',
#   'wednesday',
#   'resign',
#   'term',
#   'trigger',
#   'endorse',
#   'contraction',
#   'jim',
#   'fourthquarter',
#   'wasnt',
#   'dont',
#   'publish',
#   'current inflation',
#   'australian senate',
#   'highlyindebted mortgage',
#   'possibility employers'],
#  ['cpi',
#   'economy',
#   'market',
#   'article',
#   'finance',
#   'wharton',
#   'twitter',
#   'postcpi',
#   'share',
#   'facebook',
#   'professor',
#   'report',
#   'stronger',
#   'jeremy',
#   'response',
#   'halftime',
#   'discuss',
#   'email',
#   'linkedin',
#   'joins',
#   'sees',
#   'article facebook',
#   'professor jeremy',
#   'siegel sees'],
#  ['fund',
#   'sustainable',
#   'pictetregeneration',
#   'allocate',
#   'regulation',
#   'capital',
#   'managers',
#   'resources',
#   'emissions',
#   'inclusion',
#   'bofa',
#   'designation',
#   'disclosure',
#   'resilient',
#   'products',
#   'objective',
#   'overconsumption',
#   'counter',
#   'useful',
#   'decline',
#   'addition',
#   'worlds',
#   'latest',
#   'circular',
#   'engage',
#   'european',
#   'article',
#   'attractive',
#   'return',
#   'chamberlin',
#   'range',
#   'kulionis',
#   'gabriel',
#   'expectations',
#   'fund sustainable',
#   'management 62bn',
#   'pictet ams',
#   'thematic range'],
#  ['inflation',
#   'gas',
#   'forecast',
#   'increase',
#   'eurozone',
#   'cost',
#   'annual',
#   'utilities',
#   'current',
#   'natural',
#   'conservation',
#   'borrowing',
#   'storage',
#   'households',
#   'summer',
#   'unions',
#   'technical',
#   'negative',
#   'fears',
#   'outlook',
#   'headlines',
#   'ukraines',
#   'astronomical',
#   'manage',
#   'gleaners',
#   'downturn',
#   'range',
#   'precrisis',
#   'cut',
#   'wont',
#   'gentiloni',
#   'declare',
#   'definition',
#   'achievement',
#   'bloc',
#   'gas prices',
#   'eu countries',
#   'dampens growth',
#   'record levels'],
#  ['temples',
#   'visitors',
#   'indonesian',
#   'nft',
#   'himam',
#   'artifacts',
#   'ceremonial',
#   'collectors',
#   'quantumtemple',
#   'instagram',
#   'web3',
#   'foundation',
#   'musicians',
#   'accolade',
#   'linkedin',
#   'promote',
#   'sustainability',
#   'creative',
#   'knowledge',
#   'miami',
#   'ancestral',
#   'refreshments',
#   'newswire',
#   'physical',
#   'httpswww',
#   'logs',
#   'paths',
#   'comnewsroomattachmentng0648a885d4fe4ec2a54752967ede9b8b',
#   'friday',
#   'wagner',
#   'equitable',
#   'pandemic',
#   'katyhowl',
#   'percent',
#   'display',
#   'quantum temples',
#   'share indonesian',
#   'miami beach',
#   'development digital'],
#  ['antrim',
#   'disqualification',
#   'creditors',
#   'proceedings',
#   'nic',
#   'offence',
#   'hmrc',
#   'cloughmills',
#   'capital',
#   'contravenes',
#   'mckenna',
#   'deficiency',
#   'liquidators',
#   'executive',
#   'minimum',
#   'returns',
#   'annual',
#   'false',
#   'kilrea',
#   'permission',
#   'provision',
#   'accuracy',
#   'fine',
#   'inhibit',
#   'suggest',
#   'pressofficeeconomyni',
#   'monday',
#   'way',
#   'seriousness',
#   'channels',
#   'periods',
#   'antrim bt44',
#   'directors disqualification',
#   'contact insolvency',
#   'restated deficiency',
#   'accurate returns'],
#  ['demand',
#   'epidemic',
#   'growth',
#   'hainan',
#   'zhang',
#   'covid19',
#   'pentup',
#   'equilibrium',
#   'prioritize',
#   'sluggish',
#   'macroeconomist',
#   'pursuit',
#   'control',
#   'province',
#   'dynamic',
#   'reform',
#   'store',
#   'upgrades',
#   'inadequate',
#   'domestic',
#   'gloomy',
#   'uncertainty',
#   'conducive',
#   'securities',
#   'percent',
#   'generates',
#   'stages',
#   'underlined',
#   'fellow',
#   'hefei',
#   'ruidong',
#   'jan',
#   'integral',
#   'demand china',
#   'epidemic control',
#   'pentup potential',
#   'upgrades developing',
#   'faced sluggish'],
#  ['cybercrime',
#   'misuse',
#   'digital',
#   'statute',
#   'reform',
#   'economy',
#   'regulatory',
#   'workshop',
#   'innovative',
#   'verge',
#   'enron',
#   'email',
#   'marshall',
#   'phones',
#   'belgrave',
#   'draft',
#   'ftx',
#   'mondays',
#   'focus',
#   'current',
#   'accra',
#   'child',
#   'collapse',
#   'didnt',
#   'enable',
#   'solutions',
#   'nurture',
#   'cast',
#   'factual',
#   'poor',
#   'gritty',
#   'bernsteins',
#   'cower',
#   'jenique',
#   'combatting cybercrime',
#   'economy region',
#   'determine dust',
#   'cause recoil'],
#  ['browser',
#   'javascript',
#   'cookies',
#   'service',
#   'supports',
#   'review',
#   'policy',
#   'terms',
#   'information',
#   'happen',
#   'sure',
#   'supports javascript',
#   'loading information',
#   'did happen',
#   'review terms'],
#  ['inflation',
#   'recession',
#   'increase',
#   'unemployment',
#   'incomes',
#   'thornberg',
#   'consumers',
#   'peak',
#   'imbalances',
#   'awful',
#   'cost',
#   'average',
#   'vehicle',
#   'doomsayers',
#   'false',
#   'narrative',
#   'mirror',
#   'half',
#   'weekend',
#   'mark',
#   'shouldnt',
#   'madeup',
#   'seek',
#   'way',
#   'current',
#   'crowd',
#   'major',
#   'openings',
#   'national',
#   'interviewing',
#   'exodus',
#   'peak inflation',
#   'housing shortage',
#   'average vehicle',
#   'view mirror'],
#  ['browser',
#   'javascript',
#   'cookies',
#   'service',
#   'supports',
#   'review',
#   'policy',
#   'terms',
#   'information',
#   'happen',
#   'sure',
#   'supports javascript',
#   'loading information',
#   'did happen',
#   'review terms'],
#  ['louisiana',
#   'governor',
#   'edwards',
#   'sba',
#   'conference',
#   'grant',
#   'troy',
#   'officials',
#   'university',
#   'wafb',
#   'casillas',
#   'initiatives',
#   'usda',
#   'bel',
#   'carter',
#   'dennis',
#   'tuesday',
#   'news',
#   'broadband',
#   'plan',
#   'homes',
#   'click',
#   'spectrum',
#   'prosperity',
#   'vilsack',
#   'bring',
#   'direction',
#   'project',
#   'opportunity',
#   'small',
#   'isabella',
#   'typo',
#   'shields',
#   'copyright',
#   'louisiana news',
#   'sba administrator',
#   'congressman troy',
#   'discuss investments'],
#  ['gdp',
#   'bulgaria',
#   'quarterly',
#   'eurostat',
#   'consumption',
#   'deficit',
#   'cent',
#   'imports',
#   'trends',
#   'leva',
#   'domestic',
#   'q4',
#   'gross',
#   'real',
#   'period',
#   'nsi',
#   'releases',
#   'capital',
#   'impact',
#   'figures',
#   'independent',
#   'early',
#   'fordsxc',
#   'linkedin',
#   'reddit',
#   'basis',
#   'invasion',
#   'button',
#   'equivalent',
#   'octoberdecember',
#   'access',
#   'globe',
#   'pandemic',
#   'journalism',
#   'patron',
#   'gdp bulgaria',
#   'quarter equivalent',
#   'seasonallyadjusted data',
#   'imports rose',
#   'nsi announce'],
#  ['valley',
#   'silicon',
#   'sector',
#   'venture',
#   'francisco',
#   'layoffs',
#   'disparities',
#   'capita',
#   'trends',
#   'affordability',
#   'capitalistic',
#   'bank',
#   'pandemicdriven',
#   'asian',
#   'largescale',
#   'cycle',
#   'health',
#   'bachelors',
#   'slowdown',
#   'divides',
#   'pronounced',
#   'clawbacks',
#   'joint',
#   'inequality',
#   'josephgeha16',
#   'haves',
#   'hover',
#   'drastic',
#   'longterm',
#   'index',
#   'exist',
#   'consistent',
#   'russell',
#   'structures',
#   'despondent',
#   'focuses',
#   'silicon valley',
#   'trend affect',
#   'slowdown pandemicdriven',
#   'clawbacks adjustment',
#   'report defines'],
#  ['estonia',
#   'income',
#   'students',
#   'labor',
#   'rootalu',
#   'kadri',
#   'international',
#   'statistics',
#   'ict',
#   'receipt',
#   'engineering',
#   'eero',
#   'half',
#   'opt',
#   'source',
#   'recent',
#   'err',
#   'fields',
#   'moment',
#   'law',
#   'miss',
#   'try',
#   'day',
#   'rise',
#   'periods',
#   'pages',
#   'analyzed tax',
#   'explained rootalu',
#   'stay work',
#   'longer periods'],
#  ['board',
#   'views',
#   'conclusion',
#   'governor',
#   'table',
#   'issues',
#   'experience',
#   'member',
#   'come',
#   'time',
#   'conclusion explore',
#   'governor come',
#   'table time',
#   'issues angle'],
#  ['asean',
#   'tourismdependent',
#   'chinese',
#   'consumption',
#   'covid19',
#   'inflation',
#   'vietnams',
#   'sihanoukville',
#   'exporters',
#   'bookings',
#   'sectors',
#   'recovery',
#   'rai',
#   'threeyear',
#   'forecast',
#   'geopolitical',
#   'headwinds',
#   'airport',
#   'primechinadailyapac',
#   'kinds',
#   'metals',
#   'professor',
#   'integral',
#   'natixis',
#   'provider',
#   'normalization',
#   'rush',
#   'cushion',
#   'chinese tourists',
#   'gdp grew',
#   'look revival',
#   'components benefit'],
#  ['collegedothan',
#   'enterprise',
#   'workforce',
#   'alabamas',
#   'wallace',
#   'escc',
#   'students',
#   'fiscal',
#   'census',
#   'linda',
#   'impact',
#   'bureau',
#   'wtvy',
#   'increase',
#   'eduimpact',
#   'represent',
#   'outcomes',
#   'projects',
#   'data',
#   'young',
#   'funneling',
#   'lightcast',
#   'rigorous',
#   'www',
#   'essential',
#   'newsletter',
#   'mobile',
#   'pleased',
#   'measurable',
#   'instant',
#   'monday',
#   'alabamas economy',
#   'collegedothan results',
#   'wccd provides'],
#  ['seoul',
#   'unemployment',
#   'attn',
#   'month',
#   'inflation',
#   'sectors',
#   'kr',
#   'borrowing',
#   'gains',
#   'percentage',
#   'highest',
#   'cashier',
#   'kang',
#   'older',
#   'semiconductors',
#   'agricultural',
#   'paras',
#   'postpandemic',
#   'wednesday',
#   'flat',
#   'people',
#   'accommodation',
#   'wholesale',
#   'convenience',
#   'ministry',
#   'uncertainties',
#   'benchmark',
#   'boom',
#   'repo',
#   'recovery',
#   'file',
#   'statistics korea',
#   'yonhap unemployment',
#   'growth 314000',
#   'inflation hike',
#   'attn updates'],
#  ['gdp',
#   'rafał',
#   'growth',
#   'economy',
#   'guzpap',
#   'economists',
#   'quarter',
#   'percent',
#   'estimate',
#   'year',
#   'q4',
#   'fourth',
#   'product',
#   'shrank',
#   'data',
#   'statistical',
#   'domestic',
#   'gross',
#   'second',
#   'pap',
#   'gus',
#   'february',
#   'office',
#   'flash',
#   'central',
#   'publish',
#   'tuesday',
#   'growth second',
#   'gross domestic',
#   'polled pap'],
#  ['inflation',
#   'argentinians',
#   'forecasts',
#   'percent',
#   'reuters',
#   'poor',
#   'saluzzo',
#   'south',
#   'elections',
#   'bank',
#   'popularity',
#   'impossible',
#   'salaries',
#   'highest',
#   'chiropractor',
#   'savers',
#   'taxes',
#   'general',
#   'figure',
#   'american',
#   'hike',
#   'tuesday',
#   'worlds',
#   'theyre',
#   'vegetables',
#   'centreleft',
#   'brian',
#   'saw',
#   'argentinas inflation',
#   'leads polls'],
#  ['airbus',
#   'sector',
#   'india',
#   'engines',
#   'uks',
#   'broughton',
#   'apprenticeships',
#   'export',
#   'wings',
#   'growth',
#   'consumers',
#   'priorities',
#   'boost',
#   'domestic',
#   'trade',
#   'class',
#   'mp',
#   'rishi',
#   'filton',
#   'bring',
#   'editors',
#   'worth',
#   'limit',
#   'momentous',
#   'outside',
#   'india airbus',
#   'limit uks',
#   'powered rollsroyce',
#   'value apprenticeships'],
#  ['gdp',
#   'sectors',
#   'chinese',
#   'icloud',
#   'zhejiang',
#   'innovation',
#   'global',
#   'tencent',
#   'blockchain',
#   'monitor',
#   'fiveyear',
#   'application',
#   'tesla',
#   'scale',
#   'silk',
#   'netease',
#   'weibo',
#   'lottery',
#   'nominal',
#   'qq',
#   'sharma',
#   'pandemic',
#   'dsr',
#   'average',
#   'tiktoks',
#   'governmentrun',
#   'cuttingedge',
#   'today',
#   'ambitions',
#   'workers',
#   'compulsory',
#   'similar',
#   'assert',
#   'uyghur',
#   'unethical',
#   'behemoth',
#   'prospers scale',
#   'annually average',
#   'improve vr',
#   'compulsory obligation'],
#  ['recession',
#   'soft',
#   'texas',
#   'slowdown',
#   'wages',
#   'sectors',
#   'affordability',
#   'federal',
#   'kerr',
#   'robust',
#   'little',
#   'wake',
#   'tech',
#   'effects',
#   'sustain',
#   'recovery',
#   'spike',
#   'blown',
#   'contraction',
#   'dont',
#   'moderation',
#   'story',
#   'spill',
#   'january',
#   'covid19',
#   'pivot',
#   'population',
#   'healthy',
#   'transcript',
#   'normalization',
#   'twothirds',
#   'wrong',
#   'texas economy',
#   'pandemic recovery'],
#  ['olivier',
#   'wealth',
#   'securities',
#   'estate',
#   'planner',
#   'dentist',
#   'insurance',
#   'firm',
#   'ethical',
#   'businesses',
#   'management',
#   'practitioner',
#   'baton',
#   'louisiana',
#   'registrations',
#   'resourceful',
#   'family',
#   'writer',
#   'create',
#   'certificates',
#   'assist',
#   'innovative',
#   'association',
#   'topnotch',
#   'council',
#   'work',
#   'journal',
#   'rouge',
#   'institute',
#   'experience',
#   'continued',
#   'series',
#   'prominent',
#   'joy',
#   'addition',
#   'chad olivier',
#   'practitioner owns',
#   'louisiana dental',
#   'topnotch ethical'],
#  ['inflation',
#   'recession',
#   'forecast',
#   'imf',
#   'slowdown',
#   'shocks',
#   'covid19',
#   'countries',
#   'banks',
#   'concerns',
#   'resilience',
#   'consumer',
#   'outbreak',
#   'read',
#   'cost',
#   'energy',
#   'expansion',
#   'indication',
#   'unforeseen',
#   'october',
#   'talks',
#   'inputs',
#   'major',
#   'hikes',
#   'time',
#   'level',
#   'snag',
#   'kristalina',
#   'tunnel',
#   'global inflation',
#   'resilience levels',
#   'md kristalina'],
#  ['maines',
#   'mills',
#   'governor',
#   'shortage',
#   'investments',
#   'multimilliondollar',
#   'housing',
#   'wabi',
#   'careers',
#   'proposals',
#   'pace',
#   'fiscal',
#   'strengthen',
#   'nonpartisan',
#   'storms',
#   'measures',
#   'harbor',
#   'reporting',
#   'percent',
#   'dozen',
#   'unreal',
#   'critical',
#   'remain',
#   'message',
#   'relief',
#   'create',
#   'raroostook',
#   'elderly',
#   'faulkingham',
#   'ignores',
#   'maines revenues',
#   'multimilliondollar proposals',
#   'acquire skills'],
#  ['pangaea',
#   'crust',
#   'supercontinent',
#   'basins',
#   'carbonneutral',
#   'geothermal',
#   'margins',
#   'deposits',
#   'ultramafic',
#   'wegener',
#   'encompass',
#   'globe',
#   'marine',
#   'economy',
#   'floorbut',
#   'pérezgussinyé',
#   'origin',
#   'additional',
#   'hydrogen',
#   'forces',
#   'central',
#   'analyze',
#   'causes',
#   'cycle',
#   'populations',
#   'range',
#   'requirements',
#   'coauthors',
#   'types',
#   'reviews',
#   'accurate',
#   'simulation',
#   'rifted continental',
#   'accumulations hydrocarbon',
#   'margins authors',
#   'energy requirements'],
#  ['crisis',
#   'pakistans',
#   'economic',
#   'commodities',
#   'distress',
#   'reserves',
#   'ist',
#   'february',
#   'support',
#   'falls',
#   'data',
#   'recent',
#   'radhakrishnan',
#   'script',
#   'massive',
#   'exchange',
#   'nihalani',
#   'unpack',
#   'price',
#   'episode',
#   'story',
#   'worse',
#   'point',
#   'eggs',
#   'turbulent',
#   'jasmine',
#   'major',
#   'everyday',
#   'vignesh',
#   'ideation',
#   'loganathan',
#   'reserves pakistans',
#   'jasmine nihalani'],
#  ['sustainable',
#   'chinaeurope',
#   'partnership',
#   'economy',
#   'green',
#   'energy',
#   'philippe',
#   'policies',
#   'institute',
#   'neutrality',
#   'shi',
#   'sectors',
#   'prnewswire',
#   'brokers',
#   'models',
#   'outlook',
#   'valuable',
#   'yong',
#   'lowcarbon',
#   'leadership',
#   'platform',
#   'sophia',
#   'challenges',
#   'comparison',
#   'invigorate',
#   'park',
#   'path',
#   'common',
#   'picture',
#   'imperative',
#   'writes',
#   'peoples',
#   'counsellor',
#   'highlights',
#   'green economic',
#   'report chinese',
#   'ceo sophia',
#   'scope path'],
#  ['railway',
#   'industrys',
#   'gdp',
#   'goods',
#   'components',
#   'oxford',
#   'fleet',
#   'federal',
#   'hamilton',
#   'gasoline',
#   'footprint',
#   'multiplier',
#   'tons',
#   'ties',
#   'employee',
#   'study',
#   'ferrous',
#   'modeling',
#   'average',
#   'direct',
#   'release',
#   'signals',
#   'inbox',
#   'longdistance',
#   'enable',
#   'times',
#   'enewsletters',
#   'monday',
#   'joanna',
#   'railway gdp',
#   'supply industrys',
#   'raw materials',
#   'tax contributions'],
#  ['economy',
#   'rough',
#   'mccrann',
#   'spending',
#   'bank',
#   'panahi',
#   'waters',
#   'money',
#   'reserve',
#   'columnist',
#   'tomorrow',
#   'news',
#   'government',
#   'rita',
#   'business',
#   'policy',
#   'terry',
#   'sky',
#   'long',
#   'costs',
#   'rates',
#   'theres',
#   'function',
#   'lid',
#   'sort',
#   'host',
#   'mccrann says',
#   'waters just',
#   'theres tomorrow'],
#  ['kisun',
#   'trading',
#   'reserves',
#   'external',
#   'vice',
#   'kang',
#   'kr',
#   'speaks',
#   'semiconductors',
#   'global',
#   'energy',
#   'credit',
#   'growth',
#   'deficit',
#   'soundness',
#   'robust',
#   'united',
#   'monthly',
#   'official',
#   'meeting',
#   'default',
#   'face',
#   'chip',
#   'moodys',
#   'ministry',
#   'wednesday',
#   'decline',
#   'rating',
#   'recovery',
#   'senior',
#   'appraisers',
#   'koreas exports',
#   'stable credit',
#   'external soundness',
#   'earlier week',
#   'saying ministry'],
#  ['emissions',
#   'sustainability',
#   'democratic',
#   'policy',
#   'carbonreduction',
#   'global',
#   'breakthroughs',
#   'roadmaps',
#   'green',
#   'pandemic',
#   'pressures',
#   'solar',
#   'oil',
#   'bettercoordinate',
#   'introduction',
#   'graphene',
#   'cuts',
#   'contenders',
#   'affordability',
#   'commitment',
#   'dependencies',
#   'tax',
#   'cop27',
#   'disparate',
#   'traditions',
#   'transformation',
#   'insects',
#   'recent',
#   'uneven',
#   'theyre',
#   'backdrop',
#   'handinhand',
#   'navigate',
#   'lack',
#   'capitalise',
#   'manufacturingdriven',
#   'climate policies',
#   'multistep incremental',
#   'backdrop different',
#   'cookers lack'],
#  ['sofi',
#   'growth',
#   'forecasts',
#   'earnings',
#   'portfolio',
#   'lending',
#   'risktaker',
#   'reserves',
#   'downturn',
#   'proponents',
#   'artificial',
#   'fourthquarter',
#   'fargo',
#   'shop',
#   'onestop',
#   'pricetobook',
#   'likelier',
#   'bulls',
#   'defaults',
#   'basis',
#   'jan',
#   'terrible',
#   'score',
#   'rates',
#   'fastest',
#   'uncollateralized',
#   'limit',
#   'higherquality',
#   'story',
#   'foreign',
#   'hawkish',
#   'average',
#   'regardless',
#   'investors sofi',
#   'average pricetobook',
#   'rate environment',
#   'decreased size'],
#  ['immigration',
#   'shortage',
#   'unemployed',
#   'republicans',
#   'population',
#   'inflation',
#   'gap',
#   'biden',
#   'cuban',
#   'factors',
#   'fueling',
#   'november',
#   'apprehensions',
#   'findings',
#   'surge',
#   'desire',
#   'levels',
#   'adults',
#   'gallups',
#   'uptick',
#   'wave',
#   'carryover',
#   'bureau',
#   'miller',
#   'movements',
#   'ocasiocortez',
#   'chief',
#   'hemisphere',
#   'troy',
#   'measures',
#   'decadelow',
#   'magnuss',
#   'americans shortage',
#   'pandemic factors',
#   'background check'],
#  ['cosmetics',
#   'conspicuous',
#   'consumers',
#   'desirability',
#   'effect',
#   'forbes',
#   'coffee',
#   'spend',
#   'quantity',
#   'personal',
#   'treat',
#   'selfconfidence',
#   'females',
#   'pedicure',
#   'futurist',
#   'specialises',
#   'thats',
#   'marian',
#   'bleakest',
#   'labels',
#   'rmit',
#   'galluzzi',
#   'maternity',
#   'primal',
#   'june',
#   'treadmill',
#   'lecturer',
#   'turbulence',
#   'sydney',
#   'us6',
#   'sales lipstick',
#   'makkar rmit',
#   'coping mechanism'],
#  ['sweden',
#   'inflation',
#   'economist',
#   'eus',
#   'unemployment',
#   'forecast',
#   'mortgage',
#   'reuters',
#   'indebtedness',
#   'sector',
#   'electricity',
#   'ulf',
#   'percent',
#   'sanctions',
#   'sek',
#   'insurance',
#   'average',
#   'families',
#   'minister',
#   'uncertainty',
#   'high',
#   'recent',
#   'minimal',
#   'hotels',
#   'annual',
#   'quran',
#   'willing',
#   'commission',
#   'prepare',
#   'disposable',
#   'folksam',
#   'cow',
#   'real',
#   'uc',
#   'expected highest',
#   'rate fluctuations'],
#  ['inflation',
#   'forecasters',
#   'administrations',
#   'unemployment',
#   'easing',
#   'rouse',
#   'biden',
#   'chair',
#   'washington',
#   'affordable',
#   'nursing',
#   'bipartisan',
#   'month',
#   'sector',
#   'invest',
#   'bumps',
#   'brady',
#   'pandemic',
#   'hairdressers',
#   'average',
#   'primeage',
#   'fastest',
#   'inputs',
#   'evidence',
#   'pressures',
#   'lows',
#   'reduction',
#   'chips',
#   'sick',
#   'friday',
#   'novel',
#   'tell',
#   'signature',
#   'measures',
#   'inflation 2022',
#   'cecilia rouse',
#   'chair cautious'],
#  ['cookies',
#   'privacy',
#   'navigation',
#   'forms',
#   'analytical',
#   'necessary',
#   'enable',
#   'addresses',
#   'technologies',
#   'policy',
#   'visit',
#   'addition',
#   'identifies',
#   'choices',
#   'categories',
#   'solutions',
#   'advertising',
#   '__ga',
#   'set',
#   'tiny',
#   'downgrade',
#   'tool',
#   'describes',
#   'experience',
#   'common',
#   'measure',
#   'function',
#   'engage',
#   'thirdparty',
#   'diagnose',
#   'compile',
#   'produce',
#   'disabling cookies',
#   'use types',
#   'contact email'],
#  ['agriculture',
#   'gdp',
#   'ukrstat',
#   'ukraine',
#   'logistics',
#   'indicators',
#   'seaports',
#   'impediments',
#   'phytosanitary',
#   'operation',
#   'sectors',
#   'tons',
#   'transfers',
#   'provision',
#   'factors',
#   'competition',
#   'optimistic',
#   'peculiarities',
#   'prices',
#   'pace',
#   'devices',
#   'generators',
#   'important',
#   'institute',
#   'iron',
#   'methodology',
#   'raw',
#   'yoy',
#   'uninterruptible',
#   'ukrainian grain',
#   'gdp decline',
#   'restrict import',
#   'simultaneously january',
#   'performance transport'],
#  ['ohio',
#   'woio',
#   'orders',
#   'chips',
#   'states',
#   'hundreds',
#   'sale',
#   'productions',
#   'largest',
#   'jobs',
#   'quantity',
#   'area',
#   'india',
#   'lines',
#   'air',
#   'growth',
#   'house',
#   'agreement',
#   'happening',
#   'signals',
#   'potential',
#   'second',
#   'white',
#   'copyright',
#   'plants',
#   'new',
#   'special',
#   'chatterji',
#   'advisor',
#   'time',
#   'ronnie',
#   'implementation',
#   'advisor chips'],
#  ['reusables',
#   'sustainability',
#   'container',
#   'lifecycle',
#   'polypropylene',
#   'sanitation',
#   'singleuse',
#   'profitability',
#   'alternatives',
#   'consumes',
#   'manufacturer',
#   'serviceware',
#   'impacts',
#   'greentogo',
#   'batch',
#   'redishs',
#   'models',
#   'prevalent',
#   'prioritize',
#   'customize',
#   'esg',
#   'venues',
#   'carrie',
#   'point',
#   'vanderlips',
#   'requirements',
#   'quarter',
#   'flighttype',
#   'traction',
#   'couple',
#   'youngest',
#   'emissions water',
#   'using redishs',
#   'slow gain'],
#  ['uae',
#   'multilaterals',
#   'markets',
#   'industrial',
#   'oil',
#   'mena',
#   'mitigate',
#   'al',
#   'fragmentation',
#   'world',
#   'decades',
#   'priorities',
#   'pandemic',
#   'summit',
#   'multipolar',
#   'hub',
#   'aspect',
#   'risks',
#   'monetary',
#   'unemployed',
#   'pragmatic',
#   'succession',
#   'bin',
#   'sidelines',
#   'break',
#   'focusing',
#   'kristalina',
#   'national',
#   'headwinds',
#   'trade',
#   'touq',
#   'months',
#   'markets woke',
#   'cause fragmentation'],
#  ['monetarypolicy',
#   'bloomberg',
#   'corruption',
#   'lenders',
#   'rozhkova',
#   'capital',
#   'melitopol',
#   'reserves',
#   'future',
#   'withdrawals',
#   'advice',
#   'ministry',
#   'resilience',
#   'assess',
#   'trigger',
#   'impossible',
#   'undermining',
#   'imfs',
#   'return',
#   'recalled',
#   'cost',
#   'kudos',
#   'domestic',
#   'varnished',
#   'invasion',
#   'postcold',
#   'undisclosed',
#   'boardroom',
#   'october',
#   'registers',
#   'kiplings',
#   'foursquaremeter',
#   'bank ukraine',
#   'recalled nikolaychuk',
#   'measures prevent'],
#  ['investors',
#   'summit',
#   'proposals',
#   'ministers',
#   'crore',
#   'adityanath',
#   'gis',
#   'general',
#   'uttar',
#   'industrial',
#   'opportunities',
#   'growth',
#   'launching',
#   'world',
#   'positive',
#   'inform',
#   'interacting',
#   'underdeveloped',
#   'public',
#   'jobemployment',
#   'ground',
#   'big',
#   'congratulations',
#   'pointed',
#   'account',
#   'occasion',
#   'respective',
#   'months',
#   'example',
#   'pave',
#   'global investors',
#   'occasion yogi',
#   'departments organise',
#   'bundelkhand purvanchal'],
#  ['browser',
#   'javascript',
#   'cookies',
#   'service',
#   'supports',
#   'review',
#   'policy',
#   'terms',
#   'information',
#   'happen',
#   'sure',
#   'supports javascript',
#   'loading information',
#   'did happen',
#   'review terms'],
#  ['jakarta',
#   'economic',
#   'development',
#   'forecasts',
#   'resilience',
#   'capitals',
#   'plan',
#   'global',
#   'floods',
#   'conditions',
#   'response',
#   'spatial',
#   'downturn',
#   'central',
#   'priority',
#   'heppy',
#   'presidential',
#   'bank',
#   'head',
#   'public',
#   'able',
#   'google',
#   'consultation',
#   'tempo',
#   'extreme',
#   'conflicts',
#   'jams',
#   'tuesday',
#   'basic',
#   'jakartas economy',
#   'heru budi',
#   'updates tempo',
#   'apparatuses ensure'],
#  ['infrastructure',
#   'freelance',
#   'gig',
#   'labour',
#   'laptop',
#   'ghandour',
#   'availability',
#   'summit',
#   'executive',
#   'parttime',
#   'wamda',
#   'fadi',
#   'cost',
#   'coverage',
#   'lockdown',
#   'panel',
#   'benefit',
#   'diversify',
#   'singh',
#   'jumeirah',
#   'prevalence',
#   'advances',
#   'live',
#   'basis',
#   'questions',
#   'tuesday',
#   'residents',
#   'madinat',
#   'visa',
#   'trust',
#   'laila',
#   'outputs',
#   'havent',
#   'infrastructure remote',
#   'uae parttime',
#   'gig economy',
#   'prevalence shortterm'],
#  ['primaries',
#   'early',
#   'gop',
#   'federal',
#   'hurdles',
#   'fourth',
#   'smiths',
#   'wideopen',
#   'boast',
#   'raffensperger',
#   'firstinthesouth',
#   'ruth',
#   'tradition',
#   'critics',
#   'approval',
#   'races',
#   'ranks',
#   'chambers',
#   'downstream',
#   'risk',
#   'arm',
#   'read',
#   'assert',
#   'journalconstitution',
#   'ideal',
#   'factor georgias',
#   'scheduling overhaul',
#   'set primary',
#   'raffensperger told'],
#  ['reconstruction',
#   'pandemic',
#   'fund',
#   'economy',
#   'priority',
#   'husic',
#   'futureproof',
#   'national',
#   'aims',
#   'areas',
#   'minister',
#   'challenges',
#   'industry',
#   'weve',
#   'wednesday',
#   'question',
#   'time',
#   'ed',
#   'number',
#   'mr',
#   'address',
#   'run',
#   'help',
#   'reconstruction fund',
#   'husic national',
#   'help futureproof',
#   'number priority'],
#  ['creativity',
#   'ithra',
#   'initiative',
#   'virtual',
#   'realm',
#   'requirements',
#   'bafta',
#   'selfdevelopment',
#   'prototype',
#   'saudi',
#   'digitization',
#   'solutions',
#   'start',
#   'cycle',
#   'com',
#   'podcaster',
#   'investors',
#   'deploy',
#   'panel',
#   'aware',
#   'rotoscoped',
#   'accelerate',
#   'thats',
#   'landmark',
#   'unveil',
#   'cohorts',
#   'saklou',
#   'maram',
#   'alminhalis',
#   'kimleigh',
#   'standby',
#   'syringe',
#   'ratio',
#   'synesthesia',
#   'ithra creative',
#   'metaverse platform',
#   'augmented reality',
#   'mentorship 18week'],
#  ['valentines',
#   'income',
#   'year',
#   'lakhs',
#   'kumar',
#   'discount',
#   'fy',
#   'consumers',
#   'advancement',
#   'analytics',
#   'multinational',
#   'highest',
#   'florist',
#   'moments',
#   'consumables',
#   'covid',
#   'pvt',
#   'paytm',
#   'ways',
#   'exporter',
#   'schemes',
#   'common',
#   'galentines',
#   'alltime',
#   'flourish',
#   'definition',
#   'towns',
#   'gutgutia',
#   'billion valentines',
#   'india research',
#   'distancing covid',
#   'textbook definition'],
#  ['unfollow',
#   'groups',
#   'criteria',
#   'procedures',
#   'trends',
#   'evolve',
#   'examines',
#   'particular',
#   'signify',
#   'policy',
#   'concepts',
#   'privacy',
#   'sustainable',
#   'pertinent',
#   'acceptance',
#   'incorporate',
#   'way',
#   'copy',
#   'supra',
#   'advice',
#   'brief',
#   'intelligence',
#   'financial',
#   'email',
#   'embed',
#   'disclaimer',
#   'legal',
#   'evaluate',
#   'handbook',
#   'manager',
#   'morning',
#   'jd',
#   'unfollow follow',
#   'step building',
#   'particular situations',
#   'evaluate companies'],
#  ['economy',
#   'ukraine',
#   'russiaukraine',
#   'war',
#   'global',
#   'consequences',
#   'year',
#   'feeling',
#   'economy russiaukraine',
#   'ukraine hit',
#   'year war',
#   'feeling consequences'],
#  ['brainard',
#   'treasury',
#   'eisenhower',
#   'reserves',
#   'bidens',
#   'vice',
#   'bloomberg',
#   'deese',
#   'boushey',
#   'recession',
#   'firm',
#   'ph',
#   'deprive',
#   'board',
#   'likely',
#   'margins',
#   'layoffs',
#   'rates',
#   'south',
#   'forms',
#   'juncture',
#   'point',
#   'couple',
#   'climate',
#   'fears',
#   'statements',
#   'coronavirus',
#   'monday',
#   'bring',
#   'ramamurti',
#   'presidency brainard',
#   'markets income',
#   'chair forms',
#   'posed climate'],
#  ['inflation',
#   'sydney',
#   'cash',
#   'mortgage',
#   'pace',
#   'rba',
#   'possibility',
#   'gains',
#   'employers',
#   'resourcerich',
#   'chalmers',
#   'evidence',
#   'lowest',
#   'surge',
#   'midseptember',
#   'soft',
#   'senate',
#   'biggest',
#   'anchored',
#   'basis',
#   'risks',
#   'wednesday',
#   'resign',
#   'term',
#   'trigger',
#   'endorse',
#   'contraction',
#   'jim',
#   'fourthquarter',
#   'wasnt',
#   'dont',
#   'publish',
#   'current inflation',
#   'australian senate',
#   'highlyindebted mortgage',
#   'possibility employers'],
#  [],
#  ['fund',
#   'councils',
#   'circular',
#   'tonnes',
#   'resorts',
#   'cbd',
#   'organics',
#   'buildings',
#   'victorian',
#   'guidelines',
#   'australias',
#   'jobs',
#   'solutions',
#   'target',
#   'divert',
#   'final',
#   'regional',
#   'outline',
#   'collection',
#   'ce',
#   'repair',
#   'swan',
#   'tool',
#   'new',
#   'stories',
#   'tuesday',
#   'guide australias',
#   'apply grants',
#   'transition circular'],
#  ['recession',
#   'layoffs',
#   'tech',
#   'impact',
#   'profitability',
#   'h1b',
#   'borrowing',
#   'reductions',
#   'sectors',
#   'generation',
#   'longterm',
#   'americans',
#   'factors',
#   'lawmakers',
#   'excess',
#   'pandemic',
#   'playbook',
#   'rates',
#   'early',
#   'headwinds',
#   'worse',
#   'average',
#   'restrictions',
#   'projections',
#   'tea',
#   'openai',
#   'antecedent',
#   'fyi',
#   'industry recession',
#   'h1b visas',
#   'talent hunt',
#   'tea leaves'],
#  ['minister',
#   'fiscal',
#   'jehanzeb',
#   'ishaq',
#   'sector',
#   'prime',
#   'sapm',
#   'objectives',
#   'privatisation',
#   'imf',
#   'stabilisation',
#   'farrukh',
#   'potential',
#   'propose',
#   'disposal',
#   'inefficiencies',
#   'measures',
#   'express',
#   'cheema',
#   'chair',
#   'hayat',
#   'remittances',
#   'dividends',
#   'uddin',
#   'track',
#   'usual',
#   'expedite',
#   'basis',
#   'conversation',
#   'rs800',
#   'half',
#   'finance minister',
#   'effectiveness jehanzeb',
#   'stage task',
#   'export enhancement',
#   'use suvs'],
#  ['tianjin',
#   'chinese',
#   'xie',
#   'pandemic',
#   'economists',
#   'sectors',
#   'growth',
#   'innovations',
#   'optimism',
#   'customers',
#   'climate',
#   'air',
#   'nicolas',
#   'disruptions',
#   'slowdown',
#   'major',
#   'director',
#   'daily',
#   'agarwal',
#   'henkel',
#   'q1',
#   'outlook',
#   'stage',
#   'endtoend',
#   'rajat',
#   'footprint',
#   'recovery',
#   'row',
#   'tough',
#   'longterm',
#   'measures',
#   'remarkable',
#   'rollsroyce',
#   'categories',
#   'right',
#   'chinas economy',
#   'liquide maintained',
#   'updated 20230215',
#   'given backdrop'],
#  ['saurer',
#   'textile',
#   'equipment',
#   'mills',
#   'spinnfinity',
#   'rovings',
#   'flexible',
#   'bd',
#   'efficiency',
#   'automation',
#   'crosswound',
#   'fusiontwister',
#   'friction',
#   'circular',
#   'dhaka',
#   'texparts',
#   'wharf',
#   'highquality',
#   'eshape',
#   'solutions',
#   'zr',
#   'preparation',
#   'saves',
#   'enable',
#   'travellers',
#   'friendliness',
#   'february',
#   'spinning saurer',
#   'regenerated fibres',
#   'february dhaka',
#   'energy consumption'],
#  ['smartphone',
#   'ali',
#   'youtube',
#   'photovcg',
#   'chinese',
#   'presenter',
#   'ecommerce',
#   'newsroom',
#   'digital',
#   'reliable',
#   'cost',
#   'social',
#   'glass',
#   'source',
#   'eyeopener',
#   'possible',
#   'background',
#   'capture',
#   'outlets',
#   'growth',
#   'uptake',
#   'lifeline',
#   'goodquality',
#   'tecno',
#   'youths',
#   'unaffordable',
#   'vivos',
#   'realme',
#   'hungry',
#   'march',
#   'ready',
#   'africas smartphone',
#   'make videos',
#   'ali muslim',
#   'coming newsroom',
#   'cost renting'],
#  ['iowa',
#   'dmmc',
#   'nascent',
#   'radio',
#   'performances',
#   'assessment',
#   'impact',
#   'disparities',
#   'income',
#   'leagues',
#   'recommendations',
#   'ecosystem',
#   'labels',
#   'practices',
#   'information',
#   'shop',
#   'suburban',
#   'crossroads',
#   'politicians',
#   'nonperforming',
#   'workspace',
#   'transport',
#   'largecapacity',
#   'appendices',
#   'positive',
#   'foundation',
#   'commitment',
#   'pandemic',
#   'ease',
#   'calendar',
#   'hoyt',
#   'testament',
#   'offers',
#   'equals',
#   'unauthorized',
#   'music economy',
#   'maintains iowa',
#   'creating report',
#   'lack largecapacity'],
#  [],
#  ['flowers',
#   'ecommerce',
#   'yuan',
#   'courier',
#   'qian',
#   'agricultural',
#   'freshcut',
#   'yuyong',
#   'buy',
#   'festivals',
#   'quantity',
#   'auctioneer',
#   'luxury',
#   'fei',
#   'trend',
#   'busy',
#   'capital',
#   'fullcargo',
#   'preferences',
#   'beautiful',
#   'countrys',
#   'refrigeration',
#   'postharvest',
#   'day',
#   'confidence',
#   'unimaginable',
#   'branch',
#   'average',
#   'treatment',
#   'routine',
#   'academy',
#   'covid19',
#   'woman',
#   'lin',
#   'highquality',
#   'requirements',
#   'said chen',
#   'days average',
#   'transportation mode'],
#  ['nigeria',
#   'currencies',
#   'recession',
#   'underdeveloped',
#   'global',
#   'impacting',
#   'budget',
#   'invest',
#   'developments',
#   'policy',
#   'rate',
#   'apex',
#   'n2',
#   'stabilize',
#   'starve',
#   'cope',
#   'printing',
#   'aasame',
#   'circulation',
#   'vincent',
#   'column',
#   'yemi',
#   'relief',
#   'essayist',
#   'upside',
#   'isong',
#   'arguments',
#   'bungle',
#   'icpc',
#   'zainab',
#   'people',
#   'weeks',
#   'underdeveloped africa',
#   'rate europe',
#   'incoherent inconsistency'],
#  ['enterprise',
#   'application',
#   'institutions',
#   'polish',
#   'proenvironmental',
#   'internationalization',
#   'competencies',
#   'documentation',
#   'feng',
#   'parp',
#   'path',
#   'terms',
#   'salaries',
#   'estate',
#   'schedule',
#   'possibility',
#   'types',
#   'smart',
#   'gap',
#   'percent',
#   'size',
#   'creation',
#   'modules',
#   'digitization',
#   'infringement',
#   'horizon',
#   'modern',
#   'landreal',
#   'novelties',
#   'intensity',
#   'european ipcei',
#   'creation conditions',
#   'competencies employees',
#   'handling calls'],
#  ['uncertainty',
#   'ukraine',
#   'economy',
#   'markets',
#   'european',
#   'russias',
#   'energy',
#   'war',
#   'dependent',
#   'tight',
#   'commission',
#   'warns uncertainty',
#   'dependent russias',
#   'elevated economy',
#   'european commission',
#   'ukraine tight'],
#  ['punjab',
#   'sector',
#   'gdpgnp',
#   'bureaucracy',
#   'economysector',
#   'informal',
#   'tax',
#   'digitalization',
#   'kpk',
#   'abbas',
#   'iba',
#   'decades',
# ...
#   'renewables',
#   'feasibility',
#   'potential',
#   'plan',
#   'sectors',
#   'durban',
#   'investment',
#   'jackwell',
#   'green',
#   'cdh',
#   'reserve',
#   'jobs',
#   'impact',
#   'platinum',
#   'r160',
#   'mokopane',
#   'feris',
#   'decarbonize',
#   'core',
#   'deal',
#   'zeroemissions',
#   'alleviate',
#   'sources',
#   'stretch',
#   'hofmeyr',
#   'regulatory',
#   'sasol',
#   'kilometres',
#   'forms',
#   'flags',
#   'domestic',
#   'african economy',
#   'said feris',
#   'creating new'],
#  [],
#  ['gujarat',
#   'youth',
#   'mahatma',
#   'education',
#   'swami',
#   'governor',
#   'vedic',
#   'innovation',
#   'dharmabandhuji',
#   'katha',
#   'competitiveness',
#   'teachings',
#   'experiential',
#   'future',
#   'pransla',
#   'amrit',
#   'efforts',
#   'manoj',
#   'shivir',
#   'personality',
#   'trust',
#   'factors',
#   'change',
#   'societal',
#   'bring',
#   'practical',
#   'camp',
#   'mission',
#   'imbibe',
#   'powerful',
#   'dedicate',
#   'thoughts',
#   'platform',
#   'underlined',
#   'need',
#   'tuesday',
#   'gujarat nationallevel',
#   'youth creativity',
#   'imbibe teachings',
#   'create environment'],
#  ['ski',
#   'bakuriani',
#   'resorts',
#   'georgia',
#   'courchevel',
#   'tournament',
#   'fis',
#   'eliasch',
#   'sponsors',
#   'international',
#   'economy',
#   'freeski',
#   'evaluations',
#   'president',
#   'supervisory',
#   'silknet',
#   'ministry',
#   'launch',
#   'highlevel',
#   'best',
#   'example',
#   'destination',
#   'frances',
#   'preparation',
#   'special',
#   'sure',
#   'tracks',
#   'artificial',
#   'joint',
#   'week',
#   'telecommunication',
#   'proud',
#   'rights',
#   'categories',
#   'bakuriani hosting',
#   'resorts successful',
#   'snowboard freestyle',
#   'highlevel infrastructure',
#   'said countrys'],
#  ['recession',
#   'dunkelberg',
#   'employees',
#   'average',
#   'indicators',
#   'negative',
#   'lowest',
#   'news',
#   'index',
#   'independent',
#   'cynical',
#   'openings',
#   'percent',
#   'statement',
#   'respondents',
#   'biggest',
#   'pressures',
#   'ease',
#   'initiative',
#   'single',
#   'outlook',
#   'unqualified',
#   'linkedin',
#   'apple',
#   'basis',
#   'target',
#   'dilemma',
#   'flipboard',
#   'try',
#   'weigh',
#   'werent',
#   'daniromerotv',
#   'business optimism',
#   'index nfib',
#   'dunkelberg wrote',
#   'weigh small',
#   'monthly jobs'],
#  ['northamptonshires',
#   'survey',
#   'councils',
#   'sector',
#   'sustainable',
#   'impacts',
#   'views',
#   'offerings',
#   'interviews',
#   'walks',
#   'deputy',
#   'priorities',
#   'outline',
#   'process',
#   'people',
#   'touchpoints',
#   'english',
#   'rushden',
#   'howell',
#   'new',
#   'doors',
#   'regeneration',
#   'drink',
#   'diverse',
#   'complement',
#   'lakes',
#   'onetoone',
#   'longterm',
#   'daniel',
#   'helen',
#   'week',
#   'elements',
#   'encourage survey',
#   'investment priorities'],
#  ['goldman',
#   'recession',
#   'consumers',
#   'inflation',
#   'finances',
#   'balances',
#   'resilient',
#   'slowdown',
#   'wfc',
#   'consensus',
#   'sentiment',
#   'concern',
#   'gs',
#   'potential',
#   'signs',
#   'healthy',
#   'bac',
#   'better',
#   'availability',
#   'little',
#   'uncertainty',
#   'americas',
#   'dovish',
#   'staff',
#   'heads',
#   'nick',
#   'months',
#   'moynihan',
#   'sanguine',
#   'delinquencies',
#   'nguyen',
#   'recession consumer',
#   'york balances'],
#  ['inflation',
#   'cpi',
#   'consumer',
#   'rate',
#   'differences',
#   'assessment',
#   'wholesale',
#   'measures',
#   'wpi',
#   'directive',
#   'gauge',
#   'contain',
#   'policymakers',
#   'suggest',
#   'upper',
#   'discuss',
#   'words',
#   'data',
#   'conclusion',
#   'structure',
#   'moderate',
#   'indias',
#   'target',
#   'live',
#   'yearonyear',
#   'types',
#   'relief',
#   'way',
#   'reference',
#   'offer',
#   'limit',
#   'unlikely',
#   'legal',
#   'inflation cpi',
#   'wpi consumer',
#   'insights india',
#   'comparison types',
#   'directive word'],
#  ['rhode',
#   'indicators',
#   'economist',
#   'unemployment',
#   'lags',
#   'increase',
#   'sentiment',
#   'sales',
#   'index',
#   'layoffs',
#   'golocalprov',
#   'current',
#   'population',
#   'momentum',
#   'articles',
#   'nominal',
#   'enjoy',
#   'prof',
#   'voicing',
#   'hours',
#   'revisions',
#   'bets',
#   'relative',
#   'monthtomonth',
#   'healthy',
#   'pandemic',
#   'england',
#   'basis',
#   'diminish',
#   'bryant',
#   'concurrent',
#   'council',
#   'singleunit',
#   'indicators economic',
#   'month rhode',
#   'leonard lardaro',
#   'layoffs best',
#   'revisions rebenchmarking'],
#  ['brighton',
#   'productivity',
#   'unemployment',
#   'sectors',
#   'innovations',
#   'retail',
#   'highlevel',
#   'inflation',
#   'confidence',
#   'findings',
#   'brexit',
#   'startups',
#   'emissions',
#   'intellectual',
#   'hospitality',
#   'national',
#   'resilient',
#   'average',
#   'encompass',
#   'fastestgrowing',
#   'edge',
#   'people',
#   'director',
#   'cost',
#   'week',
#   'cebr',
#   'outlook',
#   'pandemic',
#   'cafferty',
#   'testament',
#   'business brighton',
#   'unemployment rate',
#   'highlevel qualifications',
#   'think tank'],
#  ['knowledgeworkers',
#   'informationartefacts',
#   'acquisition',
#   'drucker',
#   'conceptual',
#   'accountant',
#   'journaling',
#   'medical',
#   'relearn',
#   'aware',
#   'pursuits',
#   'analytical',
#   'fields',
#   'tbs',
#   'lead',
#   'advice',
#   'artefacts',
#   'generations',
#   'savvy',
#   'peter',
#   'baseline',
#   'propel',
#   'smartphones',
#   'capacity',
#   'openai',
#   'significant',
#   'enable',
#   'calendars',
#   'traditional',
#   'integrate',
#   'american',
#   'knowledgeworkers learn',
#   'drucker piece',
#   'described systemic',
#   'describing rise',
#   'moved priority'],
#  ['wexford',
#   'greenway',
#   'tourism',
#   'traffic',
#   'councils',
#   'rental',
#   'busy',
#   'rural',
#   'rosbercon',
#   'bottleneck',
#   'chamber',
#   'new',
#   'eateries',
#   'sustainable',
#   'beresford',
#   'attend',
#   'connick',
#   'lack',
#   'consultants',
#   'cost',
#   'encourage',
#   'lorcan',
#   'ready',
#   'potential',
#   'wouldnt',
#   'capitalise',
#   'view',
#   'scheme',
#   'similar',
#   'uptick',
#   'timeline',
#   'conjunction',
#   'properties',
#   'hive',
#   'ross municipal',
#   'greenways benefit',
#   'develop tourism',
#   'chamber work',
#   'said lot'],
#  ['mangroves',
#   'bhupendra',
#   'sector',
#   'climate',
#   'sunderbans',
#   'development',
#   'yadav',
#   'mishti',
#   'allocation',
#   'icc',
#   'biodiverse',
#   'efforts',
#   'ayan',
#   'ministry',
#   'energy',
#   'circular',
#   'petrochemical',
#   'crucial',
#   'hour',
#   'vocational',
#   'green',
#   'namaste',
#   'msme',
#   'fy',
#   'session',
#   'native',
#   'transition',
#   'eradicate',
#   'return',
#   'stats',
#   'didnt',
#   'safety',
#   'climate indias',
#   'employment circular',
#   'details fund',
#   'biodiverse spheres'],
#  ['lanka',
#   'remittances',
#   'tourism',
#   'deficit',
#   'exports',
#   'population',
#   'reserve',
#   'factors',
#   'governance',
#   'fewer',
#   'instability',
#   'terrible',
#   'climate',
#   'medicines',
#   'earnings',
#   'religiopolitical',
#   'emirates',
#   'cost',
#   'dependent',
#   'swap',
#   'populist',
#   'roots',
#   'ban',
#   'invasion',
#   'manifestations',
#   'engaged',
#   'fertilisers',
#   'needs',
#   'manifold',
#   'pledges',
#   'ascribe',
#   'cordial',
#   'lanka economic',
#   'pledges pakistans',
#   'steady pandemic',
#   'exceeded threshold'],
#  ['recession',
#   'debt',
#   'savings',
#   'gdp',
#   'annual',
#   'transactions',
#   'profitability',
#   'positive',
#   'rates',
#   'advisory',
#   'consumers',
#   'danner',
#   'health',
#   'uses',
#   'databook',
#   'factors',
#   'personal',
#   'prepandemic',
#   'signals',
#   'mercator',
#   'metric',
#   'central',
#   'comprises',
#   'right',
#   'normalization',
#   'twopart',
#   'rollover',
#   'levels',
#   'proxy',
#   'upcoming recession',
#   'card usage',
#   'danner credit',
#   'environmental factors',
#   'prepandemic levels'],
#  ['unemployment',
#   'itv',
#   'inflation',
#   'rate',
#   'earnings',
#   'sectors',
#   'encouraging',
#   'notes',
#   'latest',
#   'halve',
#   'potential',
#   'net',
#   'inactivity',
#   'fewer',
#   'times',
#   'public',
#   'real',
#   'tories',
#   'reeves',
#   'pandemic',
#   'stage',
#   'joel',
#   'hunt',
#   'vacancies',
#   'ons',
#   'pressures',
#   'uncertainty',
#   'uks unemployment',
#   'average regular'],
#  ['pandemics',
#   'sanctions',
#   'inflation',
#   'jubilee',
#   'worlds',
#   'resilience',
#   'invasion',
#   'invest',
#   'developments',
#   'russian',
#   'reversal',
#   'kipngetich',
#   'potential',
#   'sceptics',
#   'underserved',
#   'nairobi',
#   'priorities',
#   'emissions',
#   'unlikely',
#   'satellites',
#   'sh440',
#   'conversation',
#   'flows',
#   'theyre',
#   'interregional',
#   'tap',
#   'citizens',
#   'largest',
#   'dent',
#   'galvanise',
#   'openness',
#   'muscles',
#   'global disruption',
#   'monetary fiscal',
#   'ukraine february',
#   'dr julius'],
#  ['exxaros',
#   'sustainable',
#   'esg',
#   'ftse',
#   'mitigation',
#   'energy',
#   'ceo',
#   'future',
#   'governance',
#   'impact',
#   'indicator',
#   'green',
#   'tsengwa',
#   'scores',
#   'nombasa',
#   'guidance',
#   'growth',
#   'planet',
#   'exposures',
#   'factor',
#   'efforts',
#   'commodity',
#   'category',
#   'pillar',
#   'actionable',
#   'average',
#   'december',
#   'proud',
#   'grootegeluk',
#   'public',
#   'way',
#   'inequality',
#   'reflection',
#   'governance esg',
#   'climate change',
#   'organisation basic',
#   'streams underlying'],
#  ['adani',
#   'economy',
#   'bank',
#   'stocks',
#   'impact',
#   'india',
#   'borrowers',
#   'future',
#   'regulators',
#   'withdrawn',
#   'agencies',
#   'stable',
#   'conclusions',
#   'critics',
#   'corners',
#   'happenings',
#   'ports',
#   'percent',
#   'values',
#   'storm',
#   'month',
#   'brij',
#   'group',
#   'sure',
#   'normal',
#   'unique',
#   'head',
#   'story',
#   'instalments',
#   'man',
#   'foolish',
#   'lic',
#   'indian finance',
#   'happenings adani',
#   'downfall values',
#   'link performance'],
#  ['eu',
#   'correspondent',
#   'ukraine',
#   'article',
#   'monkeypox',
#   'pandemic',
#   'defence',
#   'political',
#   'medical',
#   'tomasso',
#   'mission',
#   'bid',
#   'alfaisal',
#   'cheek',
#   'edf',
#   'palavenis',
#   'ms',
#   'proposals',
#   'solution',
#   'merlo',
#   'long',
#   'way',
#   'views',
#   'domestic',
#   'criticism',
#   'terms',
#   'fund',
#   'reflect',
#   'calls',
#   'available',
#   'upadhyay',
#   'doors',
#   'european stings',
#   'pandemic article',
#   'rybarczyk opinions'],
#  ['ljubljana',
#   'incentives',
#   'tourism',
#   'businesses',
#   'financial',
#   'funds',
#   'economy',
#   'competitiveness',
#   'sports',
#   'sport',
#   'eur',
#   'institutions',
#   'year',
#   'bid',
#   'available',
#   'han',
#   'collaboration',
#   'ministry',
#   'minister',
#   'february',
#   'press',
#   'fresh',
#   'tuesday',
#   'financial incentives',
#   'tourism sports',
#   'million fresh'],
#  ['oceanology',
#   'terradepth',
#   'cloudnative',
#   'ecosystems',
#   'challenges',
#   'opensource',
#   'dataasaservice',
#   'auvs',
#   'wef',
#   'innovator',
#   'sustainable',
#   'connect',
#   'stakeholders',
#   'sensors',
#   'nations',
#   'odaas',
#   'blue',
#   'scaling',
#   'forums',
#   'efficiencies',
#   'telecommunications',
#   'information',
#   'archive',
#   'generate',
#   'wolfel',
#   'vital',
#   'novel',
#   'joe',
#   'san',
#   'fraction',
#   'conduct',
#   'ocean data',
#   'terradepth accomplishing',
#   'long endurance',
#   'innovator creating'],
#  ['mining',
#   'emissions',
#   'costs',
#   'buyback',
#   'consumer',
#   'equipment',
#   'productasaservice',
#   'competitiveness',
#   'circularity',
#   'global',
#   'capacities',
#   'mobility',
#   'invest',
#   'china',
#   'bev',
#   'dependent',
#   'players',
#   'new',
#   'models',
#   'chains',
#   'life',
#   'sovereignty',
#   'extension',
#   'normal',
#   'start',
#   'parallel',
#   'greater',
#   'resilience',
#   'secondhand',
#   'transformation',
#   'absorb',
#   'fostering',
#   'circular economy',
#   'materials lithium',
#   'buyback repair'],
#  ['msn',
#   'version',
#   'use',
#   'older',
#   'experience',
#   'best',
#   'msn experience',
#   'best msn',
#   'older browser',
#   'version best'],
#  ['inflation',
#   'pandemic',
#   'sector',
#   'pay',
#   'dow',
#   'average',
#   'easing',
#   'losses',
#   'pipeline',
#   'sluggish',
#   'reserve',
#   'broader',
#   'vodafone',
#   'england',
#   'start',
#   'cowboy',
#   'electric',
#   'toyota',
#   'todays',
#   'composite',
#   'yen',
#   'indexes',
#   'opportunistic',
#   'longest',
#   'hikes',
#   'flagship',
#   'jones',
#   'asiapacific',
#   'seng',
#   'wages grew',
#   'outside pandemic',
#   'gas pipeline',
#   'flagship electric'],
#  ['browser',
#   'javascript',
#   'cookies',
#   'service',
#   'supports',
#   'review',
#   'policy',
#   'terms',
#   'information',
#   'happen',
#   'sure',
#   'supports javascript',
#   'loading information',
#   'did happen',
#   'review terms'],
#  ['economy',
#   'corruption',
#   'value',
#   'legalised',
#   'poor',
#   'informal',
#   'regional',
#   'administration',
#   'gold',
#   'remains',
#   'size',
#   'efforts',
#   'ukbased',
#   'real',
#   'statistics',
#   'hunch',
#   'spread',
#   'us27',
#   'need',
#   'instance',
#   'utterances',
#   'uncaptured',
#   'emmerson',
#   'template',
#   'calabash',
#   'meet',
#   'week',
#   'zimbabwean economy',
#   'sector referred',
#   'worth wrote',
#   'reasons informal',
#   'understated instance'],
#  ['ljubljana',
#   'slovenias',
#   'growth',
#   'gdp',
#   'economy',
#   'annual',
#   'year',
#   'rate',
#   'february',
#   'quarter',
#   'data',
#   'statistics',
#   'office',
#   'fresh',
#   'shows',
#   'slowed annual',
#   'fresh data',
#   'office shows'],
#  ['recession',
#   'index',
#   'prices',
#   'londons',
#   'savings',
#   'analysts',
#   'technical',
#   'premier',
#   'midcap',
#   'optimism',
#   'greater',
#   'shifts',
#   'commodity',
#   'frothy',
#   'sharp',
#   'point',
#   'today',
#   'covid',
#   'margins',
#   'cautioned',
#   'shade',
#   'liberty',
#   'session',
#   'vodafone',
#   'kitwoodgetty',
#   'hargreaves',
#   'sophie',
#   'uk recession',
#   'tech stocks',
#   'forwardlooking ftse'],
#  ['bond',
#   'recession',
#   'sterling',
#   'reuters',
#   'internationallyfocused',
#   'bourse',
#   'bluechip',
#   'portfolio',
#   'riskon',
#   'policymakers',
#   'advertisement',
#   'lockdowns',
#   'suggest',
#   'aversion',
#   'upgrades',
#   'turnaround',
#   'index',
#   'biggest',
#   'gilts',
#   'basis',
#   'energy',
#   'ranasinghe',
#   'stagflation',
#   'midoctober',
#   'outlook',
#   'minibudget',
#   'naomi',
#   'multiasset',
#   'schroders',
#   'rovnick',
#   'uk recession',
#   'ahead advertisement',
#   'schroders manages'],
#  ['emissions',
#   'investments',
#   'stephenville',
#   'climate',
#   'fuelswitching',
#   'provinces',
#   'mayor',
#   'caenreleasesarchivefebruary202314c2137',
#   'cnw',
#   'federal',
#   'footprint',
#   'costs',
#   'resilience',
#   'applaud',
#   'recipients',
#   'path',
#   'hutchings',
#   'important',
#   'add',
#   'upgrade',
#   'ambitious',
#   'indigenous',
#   'ymca',
#   'netzero',
#   'tomorrow',
#   'example',
#   'httpwww',
#   'cision',
#   'good',
#   'newswire',
#   'html',
#   'canadas 2030',
#   'change fund',
#   'guilbeault minister'],
#  ['locks',
#   'mississippi',
#   'rehabilitate',
#   'dam',
#   'transportation',
#   'opportunities',
#   'investment',
#   'recreational',
#   'island',
#   'agricultural',
#   'bellevue',
#   'mechanisms',
#   'products',
#   'overdue',
#   'tom',
#   'cost',
#   'serve',
#   'politicians',
#   'reason',
#   'video',
#   'long',
#   'sites',
#   'dont',
#   'march',
#   'locks dams',
#   'restoration involves',
#   'iowa january'],
#  ['economy',
#   'roblx',
#   'strategy',
#   'nations',
#   'advancements',
#   'military',
#   'ai',
#   'midgame',
#   'guides',
#   'electronics',
#   'civstyle',
#   'reparations',
#   'areas',
#   'tax',
#   'grand',
#   'manage',
#   'generate',
#   'experience',
#   'stability',
#   'cost',
#   'walk',
#   'tycoon',
#   'stay',
#   'capture',
#   'pro',
#   'way',
#   'strongest',
#   'puppets',
#   'early',
#   'collection',
#   'vie',
#   'geological',
#   'check',
#   'high',
#   'percentage',
#   'important',
#   'mines',
#   'modifiers',
#   'neighbors',
#   'choose nation',
#   'build electronics'],
#  ['rice',
#   'farmland',
#   'yueyang',
#   'fertilizers',
#   'jiwa',
#   'county',
#   'yield',
#   'spring',
#   'equipment',
#   'gates',
#   'pebble',
#   'fourlevel',
#   'weiweion',
#   'stability',
#   'pesticides',
#   'culvert',
#   'highquality',
#   'research',
#   'groups',
#   'nyuxu',
#   'daily',
#   'flat',
#   'upgrading',
#   'multilayer',
#   'adheres',
#   'correspondent',
#   'ideology',
#   'basis',
#   'cadres',
#   'bureau',
#   'sclerotinia',
#   'vivid',
#   'graingrowing towns',
#   'numerical control',
#   'upgrading original'],
#  ['inflation',
#   'cryptocurrencies',
#   'treasury',
#   'dogecoin',
#   'price',
#   'consumer',
#   'readings',
#   'digitales',
#   'rise',
#   'tuesdays',
#   'evidence',
#   'gasoline',
#   'earnings',
#   'index',
#   'signs',
#   'core',
#   'cardano',
#   'intotheblock',
#   'point',
#   'bls',
#   'biggest',
#   'lucas',
#   'reliance',
#   'superscript',
#   'half',
#   'activos',
#   'effectiveness',
#   'basis',
#   'hikes',
#   'excludes',
#   'inflation trends',
#   'outumo decrypt',
#   'decorrelate tuesdays',
#   'report wasnt']]
