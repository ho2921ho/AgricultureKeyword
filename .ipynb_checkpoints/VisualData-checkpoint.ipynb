# %%
# !pip install konlpy

# %%
import re
from tqdm import tqdm

# %%
import openai
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import (WordCloud, get_single_color_func)
from matplotlib.pyplot import figure

# %%
class SimpleGroupedColorFunc(object):
    """Create a color function object which assigns EXACT colors
       to certain words based on the color to words mapping

       Parameters
       ----------
       color_to_words : dict(str -> list(str))
         A dictionary that maps a color to the list of words.

       default_color : str
         Color that will be assigned to a word that's not a member
         of any value from color_to_words.
    """

    def __init__(self, color_to_words, default_color):
        self.word_to_color = {word: color
                              for (color, words) in color_to_words.items()
                              for word in words}

        self.default_color = default_color

    def __call__(self, word, **kwargs):
        return self.word_to_color.get(word, self.default_color)


class GroupedColorFunc(object):
    """Create a color function object which assigns DIFFERENT SHADES of
       specified colors to certain words based on the color to words mapping.

       Uses wordcloud.get_single_color_func

       Parameters
       ----------
       color_to_words : dict(str -> list(str))
         A dictionary that maps a color to the list of words.

       default_color : str
         Color that will be assigned to a word that's not a member
         of any value from color_to_words.
    """

    def __init__(self, color_to_words, default_color):
        self.color_func_to_words = [
            (get_single_color_func(color), set(words))
            for (color, words) in color_to_words.items()]

        self.default_color_func = get_single_color_func(default_color)

    def get_color_func(self, word):
        """Returns a single_color_func associated with the word"""
        try:
            color_func = next(
                color_func for (color_func, words) in self.color_func_to_words
                if word in words)
        except StopIteration:
            color_func = self.default_color_func

        return color_func

    def __call__(self, word, **kwargs):
        return self.get_color_func(word)(word, **kwargs)

# %%
def nerByOpenAi(keyword):
    prompt="named entity recognition of korean, 경북:LOCATION, 단체장:JOB {}:".format(keyword)
    API_KEY = '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'
    openai.api_key = API_KEY

    response = openai.Completion.create(
      model="text-davinci-003",
      prompt= prompt,
      temperature=0,
      max_tokens=2500,
      top_p=1.0,
      frequency_penalty=0.0,
      presence_penalty=0.0
    )

    result = response.choices
    result = result[0].text
    tag = re.search(r"([A-Za-z]+)", result).group(1)
    return tag

# %%
import urllib3
import json

def nerByETRI(text):
    openApiURL = "http://aiopen.etri.re.kr:8000/WiseNLU" 
    accessKey = "26890e16-f465-40c0-8881-37074821de8a"
    analysisCode = "ner"
    text = text

    requestJson = {  
        "argument": {
            "text": text,
            "analysis_code": analysisCode
        }
    }

    http = urllib3.PoolManager()
    response = http.request(
        "POST",
        openApiURL,
        headers={"Content-Type": "application/json; charset=UTF-8", "Authorization" :  accessKey},
        body=json.dumps(requestJson)
    )

    result = str(response.data,"utf-8")
    json_dict = json.loads(result)
    ner = json_dict['return_object']['sentence'][0]['NE'][0]['type']
    return ner

# %%
'''
def nerByOpenAi(tags):
    keylist = ','.join(tags.index)
    prompt="경북,{} 아래과 같이 개체명 인식해줘 \n'B-LOCATION'".format(keylist)
    API_KEY = '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'
    openai.api_key = API_KEY

    response = openai.Completion.create(
      model="text-davinci-003",
      prompt="경북,{}을 아래과 같이 개체명 인식해줘 \nB-LOCATION".format(keylist),
      temperature=0,
      max_tokens=2500,
      top_p=1.0,
      frequency_penalty=0.0,
      presence_penalty=0.0
    )
    
    result = response.choices
    result = result[0].text

    tag_list = []
    kwd_list = []
    for text in result.split('\n'):
        try:
            tag = re.search(r"B-([A-Za-z]+)", text).group(1)
            korean_regex = re.compile("[ㄱ-ㅎㅏ-ㅣ가-힣]+")
            korean_text = "".join(korean_regex.findall(text))
        except:
            tag = 'null'
            korean_text = 'null'
        tag_list.append(tag)
        kwd_list.append(korean_text)
        
    ner = pd.DataFrame({"tag":tag_list},index = kwd_list)[1:]
    
    return ner
    
'''
# Out:
# '\ndef nerByOpenAi(tags):\n    keylist = \',\'.join(tags.index)\n    prompt="경북,{} 아래과 같이 개체명 인식해줘 \n\'B-LOCATION\'".format(keylist)\n    API_KEY = \'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\'\n    openai.api_key = API_KEY\n\n    response = openai.Completion.create(\n      model="text-davinci-003",\n      prompt="경북,{}을 아래과 같이 개체명 인식해줘 \nB-LOCATION".format(keylist),\n      temperature=0,\n      max_tokens=2500,\n      top_p=1.0,\n      frequency_penalty=0.0,\n      presence_penalty=0.0\n    )\n    \n    result = response.choices\n    result = result[0].text\n\n    tag_list = []\n    kwd_list = []\n    for text in result.split(\'\n\'):\n        try:\n            tag = re.search(r"B-([A-Za-z]+)", text).group(1)\n            korean_regex = re.compile("[ㄱ-ㅎㅏ-ㅣ가-힣]+")\n            korean_text = "".join(korean_regex.findall(text))\n        except:\n            tag = \'null\'\n            korean_text = \'null\'\n        tag_list.append(tag)\n        kwd_list.append(korean_text)\n
# ...

# %%
# drop_list
def dropLocation(tags, ner, org = False, slope = False):
    tag_list = []
    for keyword in pd.DataFrame(tags).index:
        try:
            tag = tmp.T[keyword]['tag']
            tag_list.append(tag)
        except:
            tag_list.append('null')

    tags_df = pd.DataFrame(tags)
    tags_df['tag'] = tag_list

    tags_df = tags_df[tags_df['tag'] != 'LOCATION']
    if org == True:
        tags_df = tags_df[tags_df['tag'] != 'ORGANIZATION']
    
    if slope == False:
        tags = tags_df['tot_cnt']
    elif slope == True:
        tags = tags_df['slope']

    return tags

# %%
def DrawPointColoredWC(tags,title,cwd,topic, drop_list=[], color = '#00ff00', pointed_list=[]):
    color_to_words = {
        color : pointed_list
    }

    use_tags = tags.drop(drop_list, errors = 'ignore')
    wc = WordCloud(font_path='C:/Windows/Fonts/malgun',background_color="white",width=1600, height=800,random_state = 1)

    default_color = 'black'
    grouped_color_func = GroupedColorFunc(color_to_words, default_color)

    cloud = wc.generate_from_frequencies(dict(use_tags))
    wc.recolor(color_func=grouped_color_func)

    figure(dpi=1200)
    figure(figsize=[12,8])
    plt.axis("off")
    plt.imshow(wc, interpolation="bilinear")
    plt.savefig(cwd + '/' + topic + '/'+ title + ' 강조'+'.pdf')
    plt.show()

# %%
def DrawWC(tags,title,cwd,topic, drop_list=[], pointed_list=[]):
    use_tags = tags.drop(drop_list,errors = 'ignore')
    wc = WordCloud(font_path='C:/Windows/Fonts/malgun',background_color="white",width=1600, height=800,random_state = 1)
    cloud = wc.generate_from_frequencies(dict(use_tags))
    figure(dpi=1200)
    figure(figsize=[12,8])
    plt.axis("off")
    plt.imshow(wc, interpolation="bilinear")
    plt.savefig(cwd + '/' + topic + '/'+ title + '.pdf')
    plt.show()

# %%
from_date = '20070101'
to_date = '20221231'
topic = '문제'

cwd = os.getcwd()
path = cwd +'/' + topic + '/raw'

df_cnt = pd.read_csv(cwd +'/' + topic + '/'+ 'Monthly_Count_Keyword {}-{}.csv'.format(from_date,to_date),index_col = 'keyword')
df_efi = pd.read_csv(cwd +'/' + topic + '/'+ 'Efficient_OLS_Keyword {}-{}.csv'.format(from_date,to_date),index_col = 'keyword')

# %%
# 머신러닝 기반이다 보니 할 때마다 다른 결과.
ners = dict()
for tag in tqdm(tags.index):
    try:
        ner = nerByETRI(tag)
        ners[tag] = ner
    except:
        print(tag)
        ner = 'etc'
        ners[tag] = ner
# Out:
#   3%|██▍                                                                              | 15/501 [00:01<00:47, 10.19it/s]
# 식품부
#   4%|███                                                                              | 19/501 [00:02<00:38, 12.65it/s]
# 청년들
#   5%|████▎                                                                            | 27/501 [00:02<00:30, 15.62it/s]
# 인력난
# 기후변화
# 농기계
#   6%|█████                                                                            | 31/501 [00:02<00:30, 15.53it/s]
# 귀촌
# 노동력
#   7%|█████▉                                                                           | 37/501 [00:03<00:28, 16.11it/s]
# 빅데이터
# 농작업
# 사업비
#   9%|██████▉                                                                          | 43/501 [00:03<00:28, 16.36it/s]
# 위원회
#   9%|███████▌                                                                         | 47/501 [00:03<00:26, 17.25it/s]
# 지속가능
# ...

# %%
drop_list = []

# %%
result = [key for key, value in ners.items() if value == 'OGG_POLITICS']
result
# Out:
# ['더불어민주당',
#  '농식품부',
#  '한국당',
#  '노동당',
#  '환경부',
#  '정의당',
#  '교육부',
#  '자유한국당',
#  '행정안전부',
#  '기재부',
#  '농촌진흥청',
#  '대통령실',
#  '행정복지센터',
#  '면사무소',
#  '경기도의회',
#  '국토교통부',
#  '통계청',
#  '정치국',
#  '시의회',
#  '교통부',
#  '아세안',
#  '바른미래당',
#  '국토부',
#  '중앙위원회',
#  '고용노동부',
#  '노동부',
#  '농업기술실용화재단',
#  '국민의당',
#  '진흥원',
#  '산림청',
#  '해수부',
#  '민주평화당',
#  '총비서',
#  '공화당']

# %%
drop_list.extend(result)

# %%
result = [key for key, value in ners.items() if value == 'PS_NAME']
result
# Out:
# ['고령화',
#  '문재인',
#  '김정은',
#  '이재명',
#  '윤석열',
#  '도널드',
#  '시진핑',
#  '영농철',
#  '세종',
#  '이철우',
#  '미중',
#  '김영록',
#  '김현수',
#  '정황근',
#  '홍남기',
#  '바이든',
#  '장기화',
#  '지원',
#  '이개호',
#  '푸틴',
#  '이성희',
#  '김동연',
#  '신재생',
#  '이낙연',
#  '푸드플랜',
#  '서삼석',
#  '알리바바',
#  '김여정',
#  '조병옥',
#  '메타버스',
#  '강수량',
#  '김돈곤',
#  '김태흠',
#  '리빙랩',
#  '성일종',
#  '양승조',
#  '폼페이오',
#  '고용주',
#  '최재형',
#  '김영',
#  '브렉시트']

# %%
result.remove('고령화')
result.remove('영농철')
result.remove('미중')
result.remove('장기화')
result.remove('지원')
result.remove('푸드플랜')
result.remove('강수량')
result.remove('고용주')
result.remove('메타버스')
result.remove('브렉시트')

drop_list.extend(result)

# %%
result = [key for key, value in ners.items() if 'LCP' in value]
result
# Out:
# ['경북',
#  '대한민국',
#  '전남',
#  '우크라이나',
#  '러시아',
#  '경기도',
#  '귀농귀촌',
#  '경북도',
#  '괴산군',
#  '전북',
#  '충북',
#  '충남',
#  '강원도',
#  '강원',
#  '당진시',
#  '청양군',
#  '대구',
#  '영국',
#  '전남도',
#  '노지',
#  '전라북도',
#  '괴산',
#  '베트남',
#  '부여군',
#  '익산시',
#  '전라남도',
#  '진천군',
#  '의성군',
#  '청양',
#  '서산시',
#  '여주시',
#  '개발도상국',
#  '청주시',
#  '나주',
#  '두류',
#  '고창군',
#  '홍콩',
#  '의성',
#  '고흥',
#  '광주시',
#  '상해',
#  '나주시',
#  '경상북도',
#  '옥천군',
#  '네덜란드',
#  '이천시',
#  '제천시',
#  '포천',
#  '경남',
#  '곡성군',
#  '대남',
#  '대구경북',
#  '영동군',
#  '하노이',
#  '익산',
#  '영양군',
#  '한국판',
#  '캄보디아',
#  '고흥군',
#  '조선',
#  '코로',
#  '인천',
#  '무주군',
#  '순천']

# %%
result.remove('우크라이나')
result.remove('개발도상국')
result.remove('러시아')
result.remove('베트남')
result.remove('캄보디아')
result.remove('네덜란드')
result.remove('영국')
drop_list.extend(result)

# %%
result = ['중부매일','서울시','임시회','촬영기자','개정안','국민의힘','한국농어촌공사','노동신문','내년도','참여자','보고서','시간date','충북일보','식품부','농림축산식품부','코로나19','호남','분들','그다음']
drop_list.extend(result)

# %%
title = '최대빈도순'
tags = df_cnt.sort_values(by = 'tot_cnt', ascending = False)[1:501]['tot_cnt']

# %%
DrawWC(tags = tags, title =title,cwd = cwd,topic = topic,drop_list = drop_list)

# %%
title = '상승키워드'
tags = df_efi.sort_values(by = 'slope', ascending = False)[:501]['slope']

# %%
DrawWC(tags = tags[0:500], title =title,cwd = cwd,topic = topic,drop_list = drop_list)

# %%
from_date = '20200101'
to_date = '20221231'
topic = '비용'

cwd = os.getcwd()
path = cwd +'/' + topic + '/raw'

df_cnt = pd.read_csv(cwd +'/' + topic + '/'+ 'Monthly_Count_Keyword {}-{}.csv'.format(from_date,to_date),index_col = 'keyword')

pointedTag_cost = df_cnt.sort_values(by = 'tot_cnt', ascending = False)[0:501]['tot_cnt']

from_date = '20200101'
to_date = '20221231'
topic = '식량안보'

cwd = os.getcwd()
path = cwd +'/' + topic + '/raw'

df_cnt = pd.read_csv(cwd +'/' + topic + '/'+ 'Monthly_Count_Keyword {}-{}.csv'.format(from_date,to_date),index_col = 'keyword')

pointedTag_security = df_cnt.sort_values(by = 'tot_cnt', ascending = False)[0:501]['tot_cnt']

from_date = '20200101'
to_date = '20221231'
topic = '불평등'

cwd = os.getcwd()
path = cwd +'/' + topic + '/raw'

df_cnt = pd.read_csv(cwd +'/' + topic + '/'+ 'Monthly_Count_Keyword {}-{}.csv'.format(from_date,to_date),index_col = 'keyword')

pointedTag_inequality = df_cnt.sort_values(by = 'tot_cnt', ascending = False)[0:501]['tot_cnt']

# %%
# norlize

# %%
pointedTag_cost = pointedTag_cost / pointedTag_cost['year_cnt']
pointedTag_cost.name = 'cost'

pointedTag_security = pointedTag_security / pointedTag_security['year_cnt']
pointedTag_security.name = 'security'

pointedTag_inequality = pointedTag_inequality / pointedTag_inequality['year_cnt']
pointedTag_inequality.name = 'inequality'

# %%
# compare
result = pd.concat([pointedTag_cost, pointedTag_security , pointedTag_inequality ], axis=1, join='outer', ignore_index=False).fillna(0)
result['mean'] = result.mean(axis = 1)

divisor = 'mean'

new_df = result.div(result[divisor], axis=0)

# %%
title = '비용 강조'
pointedTag_cost = new_df['cost'].sort_values(ascending = False)[:300]
DrawPointColoredWC(tags = tags[0:500], title =title,cwd = cwd,topic = '문제',drop_list = drop_list,pointed_list=pointedTag_cost.index)

# %%
title = '식량안보 강조'
pointedTag_security = new_df['security'].sort_values(ascending = False)[:300]
DrawPointColoredWC(tags = tags[0:500], color = '#ff0000',title =title,cwd = cwd,topic = '문제',drop_list = drop_list,pointed_list=pointedTag_security.index)

# %%
title = '불평등'
pointedTag_inequality = new_df['inequality'].sort_values(ascending = False)[:350]
DrawPointColoredWC(tags = tags[0:500], color = '#0000ff', title =title,cwd = cwd,topic = '문제',drop_list = drop_list,pointed_list=pointedTag_inequality.index)
