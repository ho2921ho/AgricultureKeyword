# %%
from datetime import datetime
import logging
import re
import numpy as np
import pandas as pd
import os
import pickle
import networkx as nx
from pyvis.network import Network

# 워드 클라우드
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

from matplotlib.pyplot import figure

from wordcloud import (WordCloud, get_single_color_func)

# %%
class SimpleGroupedColorFunc(object):
    """Create a color function object which assigns EXACT colors
       to certain words based on the color to words mapping

       Parameters
       ----------
       color_to_words : dict(str -> list(str))
         A dictionary that maps a color to the list of words.

       default_color : str
         Color that will be assigned to a word that's not a member
         of any value from color_to_words.
    """

    def __init__(self, color_to_words, default_color):
        self.word_to_color = {word: color
                              for (color, words) in color_to_words.items()
                              for word in words}

        self.default_color = default_color

    def __call__(self, word, **kwargs):
        return self.word_to_color.get(word, self.default_color)


class GroupedColorFunc(object):
    """Create a color function object which assigns DIFFERENT SHADES of
       specified colors to certain words based on the color to words mapping.

       Uses wordcloud.get_single_color_func

       Parameters
       ----------
       color_to_words : dict(str -> list(str))
         A dictionary that maps a color to the list of words.

       default_color : str
         Color that will be assigned to a word that's not a member
         of any value from color_to_words.
    """

    def __init__(self, color_to_words, default_color):
        self.color_func_to_words = [
            (get_single_color_func(color), set(words))
            for (color, words) in color_to_words.items()]

        self.default_color_func = get_single_color_func(default_color)

    def get_color_func(self, word):
        """Returns a single_color_func associated with the word"""
        try:
            color_func = next(
                color_func for (color_func, words) in self.color_func_to_words
                if word in words)
        except StopIteration:
            color_func = self.default_color_func

        return color_func

    def __call__(self, word, **kwargs):
        return self.get_color_func(word)(word, **kwargs)

# %%
# 날짜 및 검색어 설정
from_date = '20230313'
to_date = '20230313'
topic = 'economy'

# %%
# 데이터 전처리
cwd = os.getcwd()
path = cwd +'/' + topic + '/raw'

df_cnt = pd.read_csv(cwd +'/' + topic + '/'+ 'Monthly_Count_Keyword {}-{}.csv'.format(from_date,to_date),index_col = 'keyword')

main_path = cwd + '/' + topic
name = "Keyword{}-{}.pickle".format(from_date,to_date)
name = name.replace('/','.')
with open(main_path + '/' + 'keyword/' + name, 'rb') as f:
    data_e = pickle.load(f)
    
result = data_e[['일자','url']].explode('url').reset_index(drop=True)
url_long_data = result.explode('url').reset_index(drop=True)

keyword_long_data = data_e[['일자','키워드']].explode('키워드').reset_index(drop=True)

print('{}로 검색하여 {}부터 {}까지 {} 건의 기사를 인용했습니다.'.format(topic,from_date,to_date,len(url_long_data )))
# Out:
# economy로 검색하여 20230313부터 20230313까지 210 건의 기사를 인용했습니다.

# %%
# 최대 키워드 수, 지울 단어, 강조할 단어 지정
num = 100
drop_list = [np.nan]
color_to_words = {
    '#00ff00': ['silicon','inflation','outlook','pandemic','recession','sectors']
}

# %%
# 그림 그리기 및 저장
tags = df_cnt.sort_values(by = 'tot_cnt', ascending = False)[1:num+1]['tot_cnt']
tags = tags.drop(drop_list)
wc = WordCloud(font_path='C:/Windows/Fonts/malgun',background_color="white",width=1600, height=800)
default_color = 'black'
grouped_color_func = GroupedColorFunc(color_to_words, default_color)

cloud = wc.generate_from_frequencies(dict(tags))
wc.recolor(color_func=grouped_color_func)

figure(dpi=1200)
figure(figsize=[12,8])
title = '대상기간_최대출현_키워드_100개'
plt.axis("off")
plt.imshow(wc, interpolation="bilinear")
plt.savefig(cwd + '/' + topic + '/'+ title + from_date + '.pdf')
plt.show()

# %%
# 키워드의 뉴스링크

# %%
keyword = 'sectors'

# %%
tmp = []
for i in keyword_long_data['키워드']:
    if keyword in i:
        tmp.append(True)
    else:
        tmp.append(False)

for url in url_long_data[tmp]['url']:
    print(url)
# Out:
# https://businessplus.ie/economy/economy-good-friday/
# https://www.bnamericas.com/en/interviews/seeing-the-circular-economy-as-smart-business-not-just-environmental-responsibility
# https://www.zeebiz.com/economy-infra/news-blue-economy-and-ai-prominent-sectors-cannot-be-ingored-cag-225628
# https://www.swansea.ac.uk/press-office/news-events/news/2023/03/conference-to-highlight-how-circular-economy-can-shape-future-for-wales.php
# https://businessday.ng/business-economy/article/what-tinubus-presidency-means-for-the-economy/
# https://www.thehindubusinessline.com/markets/commodities/crude-oil-declines-as-svb-failure-impacts-us-economy/article66617501.ece
# https://www.crainscleveland.com/opinion/personal-view-northeast-ohio-needs-prepare-economy-future
# https://economicconfidential.com/2023/03/report-reveals-economy-lost/
# https://www.thespec.com/business/2023/03/13/inflation-and-high-interest-rates-to-dampen-hamiltons-economy-this-year.html
# https://www.globaltimes.cn/page/202303/1287236.shtml
# https://www.baynews9.com/fl/tampa/news/2023/03/12/uhero--local-economy-will-slow-but-no-recession-ahead
# https://www.thehindu.com/opinion/editorial/a-fragile-momentum/article66614934.ece
# https://www.irishexaminer.com/business-columnists/arid-41091838.html
# https://www.businessinsider.com/stock-market-investing-strategy-recession-inflation-outlook-optimal-portfolio-morningstar-2023-3
# https://www.presstv.ir/Detail/2023/03/13/699812/Iran-economic-growth-December-quarter-CBI-figures
# https://economynext.com/sri-lanka-unions-threaten-to-cripple-economy-against-imf-backed-reforms-115297/
# https://saudigazette.com.sa/article/630665/BUSINESS/Innovation-and-Entrepreneurship-in-Driving-Growth-within-the-Saudi-Arabian-Economy-and-Markets
# https://sunlive.co.nz/news/314841-life-sciences-crucial-future-on-nzs-economy.html
# https://www.business-standard.com/article/news-cm/ficci-s-manufacturing-survey-says-momentum-of-growth-has-continued-for-domestic-economy-123031300535_1.html
# https://ca.finance.yahoo.com/news/svbs-downfall-shows-fed-broke-132924600.html
# https://agenda.ge/en/news/2023/1030
# http://www.china.org.cn/world/Off_the_Wire/2023-03/14/content_85167370.htm
# https://www.einnews.com/pr_news/621504319/wasseem-dirani-discusses-inflation-and-the-canadian-economy
# https://www.tasnimnews.com/en/news/2023/03/13/2867166/iran-iraq-taking-giant-stride-to-strengthen-bilateral-trade
# https://newslivetv.com/gupta-brothers-founders-of-ashoka-university-explain-how-foreign-universities-can-boost-indias-knowledge-economy/
# https://saudigazette.com.sa/article/630670/SAUDI-ARABIA/MEP-MAEE-sign-MoU-to-safeguard-water-and-financial-sustainability
# https://crypto-economy.com/japanese-automobile-giant-nissan-enter-metaverse-files-4-new-web3-trademarks/
